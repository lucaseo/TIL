# %%
from selenium import webdriver
import pandas as pd
import datetime

# %%
melon_day = pd.DataFrame(columns = ["Ranking", "Song", "Artist", "Album"])
melon_day
# Out:
# Empty DataFrame
# Columns: [Ranking, Song, Artist, Album]
# Index: []

# %%
# 1~50
url = "https://www.melon.com/chart/day/index.htm"

# %%
driver = webdriver.PhantomJS("/Users/Seoluca/Data_Analytics/Git/TIL/TIL/2_python_Packages_Libraries/06_selenium/01_reviewNote_selenium/phantomJS/phantomJS")

# %%
driver.get(url)

# %%
table_50 = driver.find_elements_by_css_selector("#tb_list tbody #lst50")

# %%
table_50
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866201")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866202")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866203")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866204")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866205")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866206")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866207")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866208")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866209")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866211")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866212")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866213")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866215")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866216")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866217")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866218")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866221")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866222")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866223")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866224")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866225")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866226")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866227")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866228")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866229")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866230")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866231")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866232")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866233")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866234")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866235")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866236")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866237")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866239")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866240")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866241")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866242")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866243")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866244")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866245")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866246")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866247")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866248")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866249")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6db78c50-1ef0-11e8-aec0-65bdceb348f9", element=":wdc:1520087866250")>]

# %%
for table in table_50:

    rank = table.find_element_by_css_selector(".rank").text
    song = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank01 a").text
    artist = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank02 a").text
    album = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank03 a").text

    data = {"Ranking" : rank, 
            "Song" : song, 
            "Artist" : artist, 
            "Album" : album, }

    melon_day.loc[len(melon_day)] = data

# %%
melon_day
# Out:
#    Ranking                             Song               Artist  \
# 0        1           사랑을 했다 (LOVE SCENARIO)                 iKON
# 1        2                               뿜뿜      모모랜드 (MOMOLAND)
# 2        3                             그날처럼                  장덕철
# 3        4                        그때 헤어지면 돼                  로이킴
# 4        5                          Bad Boy    Red Velvet (레드벨벳)
# 5        6        Havana (Feat. Young Thug)       Camila Cabello
# 6        7                   Roller Coaster                   청하
# 7        8                               선물                 멜로망스
# 8        9                         HandClap  Fitz & The Tantrums
# 9       10                              비행운        문문 (MoonMoon)
# 10      11                              주인공                   선미
# 11      12                              눈사람                  정승환
# 12      13                        instagram                 DEAN
# 13      14                             #첫사랑               볼빨간사춘기
# 14      15                           밤이 되니까           펀치 (Punch)
# 15      16                              이 별                 길구봉구
# 16      17                     Heart Shaker         TWICE (트와이스)
# 17      18                               좋니                  윤종신
# 18      19                           My Way         이수 (엠씨 더 맥스)
# 19      20                   all of my life                   박원
# 20      21                    다른사람을 사랑하고 있어            수지 (SUZY)
# 21      22                            가을 안부               먼데이 키즈
# 22      23                              DNA                방탄소년단
# 23      24                     Shape of You           Ed Sheeran
# 24      25                      눈 떠보니 이별이더라                   포맨
# 25      26                            LIKEY         TWICE (트와이스)
# 26      27                          기억의 빈자리                   나얼
# 27      28                            그리워하다                  비투비
# 28      29                               답장                  김동률
# 29      30    시차 (We Are) (Feat. 로꼬 & GRAY)                  우원재
# 30      31                 피카부 (Peek-A-Boo)    Red Velvet (레드벨벳)
# 31      32                               좋아                   민서
# 32      33                              밤편지                  아이유
# 33      34                            썸 탈꺼야               볼빨간사춘기
# 34      35                              You                 멜로망스
# 35      36  There`s Nothing Holdin` Me Back         Shawn Mendes
# 36      37                    그때의 나, 그때의 우리                어반자카파
# 37      38                        Beautiful      Wanna One (워너원)
# 38      39            비도 오고 그래서 (Feat. 신용재)          헤이즈 (Heize)
# 39      40                               봄날                방탄소년단
# 40      41                               노력                   박원
# 41      42                              바보야                   허각
# 42      43                Lonely (Feat. 태연)        종현 (JONGHYUN)
# 43      44                     첫눈처럼 너에게 가겠다                  에일리
# 44      45                              가시나                   선미
# 45      46                              고맙다                  세븐틴
# 46      47                 연애소설 (Feat. 아이유)     에픽하이 (EPIK HIGH)
# 47      48                빨간 맛 (Red Flavor)    Red Velvet (레드벨벳)
# 48      49                     바람이 불었으면 좋겠어                 길구봉구
# 49      50                              짙어져                 멜로망스
#
#                                                Album
# 0                                             Return
# 1                                             GREAT!
# 2                                               그날처럼
# 3                                          그때 헤어지면 돼
# 4   The Perfect Red Velvet - The 2nd Album Repackage
# 5                                             Camila
# 6                                             Offset
# 7                                          Moonlight
# 8                     Fitz and The Tantrums (Deluxe)
# 9                                LIFE IS BEAUTY FULL
# 10                                               주인공
# 11                                             그리고 봄
# 12                                         instagram
# 13                                              #첫사랑
# 14                                            밤이 되니까
# 15                                              Star
# 16                                     Merry & Happy
# 17                                     LISTEN 010 좋니
# 18                                     돈꽃 OST Part.1
# 19                                                0M
# 20                                     Faces of Love
# 21                                             가을 안부
# 22                             LOVE YOURSELF 承 `Her`
# 23                                        ÷ (Deluxe)
# 24                                       REMEMBER ME
# 25                                       twicetagram
# 26                                           기억의 빈자리
# 27                                      Brother Act.
# 28                                                답장
# 29                                       시차 (We Are)
# 30                    Perfect Velvet - The 2nd Album
# 31                                  2017 월간 윤종신 11월호
# 32                                               밤편지
# 33                                  Red Diary Page.1
# 34                             투유 프로젝트 - 슈가맨2 Part.2
# 35                      Illuminate (New Deluxe Ver.)
# 36                                     그때의 나, 그때의 우리
# 37                       1-1=0 (NOTHING WITHOUT YOU)
# 38                                     /// (너 먹구름 비)
# 39                              YOU NEVER WALK ALONE
# 40                                              1/24
# 41                                               바보야
# 42                                 종현 소품집 `이야기 Op.2`
# 43                                    도깨비 OST Part.9
# 44                       SUNMI SPECIAL EDITION `가시나`
# 45          SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`
# 46                    WE`VE DONE SOMETHING WONDERFUL
# 47                The Red Summer - Summer Mini Album
# 48                                      바람이 불었으면 좋겠어
# 49                                 Yellow OST Part.2

# %%
# 51~100
driver.get("https://www.melon.com/chart/day/index.htm#params%5Bidx%5D=51")

# %%
# driver.find_element_by_xpath("""//*[@id="tb_list"]/div/span/a""").click()

# %%
table_100 = driver.find_elements_by_css_selector("#tb_list tbody .lst100")

# %%
for table in table_100:

    rank = table.find_element_by_css_selector(".rank").text
    song = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank01 a").text
    artist = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank02 a").text
    album = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank03 a").text

    data = {"Ranking" : rank, 
            "Song" : song, 
            "Artist" : artist, 
            "Album" : album, }

    melon_day.loc[len(melon_day)] = data

# %%
melon_day = melon_day.set_index('Ranking')

# %%
driver.close()

# %%
melon_day
# Out:
#                                   Song               Artist  \
# Ranking
# 1               사랑을 했다 (LOVE SCENARIO)                 iKON
# 2                                   뿜뿜      모모랜드 (MOMOLAND)
# 3                                 그날처럼                  장덕철
# 4                            그때 헤어지면 돼                  로이킴
# 5                              Bad Boy    Red Velvet (레드벨벳)
# 6            Havana (Feat. Young Thug)       Camila Cabello
# 7                       Roller Coaster                   청하
# 8                                   선물                 멜로망스
# 9                             HandClap  Fitz & The Tantrums
# 10                                 비행운        문문 (MoonMoon)
# 11                                 주인공                   선미
# 12                                 눈사람                  정승환
# 13                           instagram                 DEAN
# 14                                #첫사랑               볼빨간사춘기
# 15                              밤이 되니까           펀치 (Punch)
# 16                                 이 별                 길구봉구
# 17                        Heart Shaker         TWICE (트와이스)
# 18                                  좋니                  윤종신
# 19                              My Way         이수 (엠씨 더 맥스)
# 20                      all of my life                   박원
# 21                       다른사람을 사랑하고 있어            수지 (SUZY)
# 22                               가을 안부               먼데이 키즈
# 23                                 DNA                방탄소년단
# 24                        Shape of You           Ed Sheeran
# 25                         눈 떠보니 이별이더라                   포맨
# 26                               LIKEY         TWICE (트와이스)
# 27                             기억의 빈자리                   나얼
# 28                               그리워하다                  비투비
# 29                                  답장                  김동률
# 30       시차 (We Are) (Feat. 로꼬 & GRAY)                  우원재
# ...                                ...                  ...
# 71                               비가 온다                  정승환
# 72                                  한숨                  이하이
# 73                             네가 없는 곳                  양요섭
# 74                                어디에도                엠씨더맥스
# 75                               Power                  EXO
# 76                            MIC Drop                방탄소년단
# 77                                   별                  양요섭
# 78                              애쓰지 마요                  박보람
# 79                팔레트 (Feat. G-DRAGON)                  아이유
# 80                       눈 (Feat. 이문세)               Zion.T
# 81                                 덜덜덜                 EXID
# 82                             Tell Me                 인피니트
# 83                              피 땀 눈물                방탄소년단
# 84                                  박수                  세븐틴
# 85            HOLIDAY (Feat. DPR LIVE)            수지 (SUZY)
# 86          What Lovers Do (Feat. SZA)             Maroon 5
# 87                      봉제선 (Feat. 수란)              다이나믹 듀오
# 88                                여보세요               NU`EST
# 89               지나갈 테니 (Been Through)                  EXO
# 90                           True Love                  김성규
# 91                        지금 널 찾아가고 있어                  세븐틴
# 92                        WHERE YOU AT               뉴이스트 W
# 93                    LONG TIME NO SEE                 iKON
# 94                          남이 될 수 있을까               볼빨간사춘기
# 95                          Chandelier                  Sia
# 96                          Best Of Me                방탄소년단
# 97                  Thinkin` about you                  세븐틴
# 98                                  행복               H.O.T.
# 99                         사랑하지 않은 것처럼                   버즈
# 100                       마지막으로 안아도 될까                   허각
#
#                                                     Album
# Ranking
# 1                                                  Return
# 2                                                  GREAT!
# 3                                                    그날처럼
# 4                                               그때 헤어지면 돼
# 5        The Perfect Red Velvet - The 2nd Album Repackage
# 6                                                  Camila
# 7                                                  Offset
# 8                                               Moonlight
# 9                          Fitz and The Tantrums (Deluxe)
# 10                                    LIFE IS BEAUTY FULL
# 11                                                    주인공
# 12                                                  그리고 봄
# 13                                              instagram
# 14                                                   #첫사랑
# 15                                                 밤이 되니까
# 16                                                   Star
# 17                                          Merry & Happy
# 18                                          LISTEN 010 좋니
# 19                                          돈꽃 OST Part.1
# 20                                                     0M
# 21                                          Faces of Love
# 22                                                  가을 안부
# 23                                  LOVE YOURSELF 承 `Her`
# 24                                             ÷ (Deluxe)
# 25                                            REMEMBER ME
# 26                                            twicetagram
# 27                                                기억의 빈자리
# 28                                           Brother Act.
# 29                                                     답장
# 30                                            시차 (We Are)
# ...                                                   ...
# 71                                                  그리고 봄
# 72                                               SEOULITE
# 73                         YANG YOSEOP 2ND MINI ALBUM `白`
# 74                                                 pathos
# 75           The Power of Music - The 4th Album Repackage
# 76                                  LOVE YOURSELF 承 `Her`
# 77                         YANG YOSEOP 2ND MINI ALBUM `白`
# 78                                                 애쓰지 마요
# 79                                                Palette
# 80                                                      눈
# 81                                              Full Moon
# 82                                               TOP SEED
# 83                                                  WINGS
# 84                        SEVENTEEN 2ND ALBUM `TEEN, AGE`
# 85                                          Faces of Love
# 86                        Red Pill Blues (Deluxe Edition)
# 87                                                    봉제선
# 88                           THE SECOND MINI ALBUM `여보세요`
# 89                             Universe - 겨울 스페셜 앨범, 2017
# 90                                 1st Album `10 Stories`
# 91               SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`
# 92                                                W, HERE
# 93                                                 Return
# 94                                             남이 될 수 있을까
# 95                                    Chandelier (Single)
# 96                                  LOVE YOURSELF 承 `Her`
# 97               SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`
# 98                                         Wolf and Sheep
# 99                     `Be One` - Buzz The 1st Mini Album
# 100                                          마지막으로 안아도 될까
#
# [100 rows x 3 columns]

# %%
now = datetime.datetime.now()
current_time = now.strftime("%Y-%m-%d")
current_time
# Out:
# '2018-03-03'

# %%
melon_day.to_csv('melon_daily_100(' + str(current_time) + ')' )

# %%
% ls
# Out:
# 01_selenium_webdriver_intro.ipynb
# 02_selenium_webdriver_file_uploading.ipynb
# 03_selenium_webdriver_image_(pillow).ipynb
# 2018-03-03 23:38:04melon_daily_100
# 2018-03-03 : melon_daily_100
# ghostdriver.log
# melon_chart_100
# melon_daily_100(2018-03-03)
# melon_day_100
# melon_weekly_100
# phantomJS/
# phantomJS practice 2.ipynb
# phantomJS practice.ipynb

# %%
melon_day = pd.read_csv('melon_day_100')

# %%
melon_day
