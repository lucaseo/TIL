# %%
from selenium import webdriver
import pandas as pd

# %%
melon_100 = pd.DataFrame(columns = ["Ranking", "Song", "Artist", "Album"])
melon_100
# Out:
# Empty DataFrame
# Columns: [Ranking, Song, Artist, Album]
# Index: []

# %%
# 1~50
url = "http://www.melon.com/chart/day/index.htm"

# %%
driver = webdriver.Chrome()

# %%
driver.get(url)

# %%
table_50 = driver.find_elements_by_css_selector("#tb_list tbody #lst50")

# %%
# get data of ranking 1~50

for table in table_50:
    
    rank = table.find_element_by_css_selector(".rank").text
    song = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank01 a").text
    artist = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank02 a").text
    album = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank03 a").text
    
    data = {"Ranking" : rank, 
            "Song" : song, 
            "Artist" : artist, 
            "Album" : album, }
    
    melon_100.loc[len(melon_100)] = data

# %%
melon_100
# Out:
#    Ranking                           Song               Artist  \
# 0        1         바코드 (Prod. GroovyRoom)           김하온 (HAON)
# 1        2                            꽃 길              BIGBANG
# 2        3                       별이 빛나는 밤                  마마무
# 3        4         사랑을 했다 (LOVE SCENARIO)                 iKON
# 4        5                  북 (Prod. SLO)      배연서 (WEBSTER B)
# 5        6                             뿜뿜      모모랜드 (MOMOLAND)
# 6        7                           그날처럼                  장덕철
# 7        8            Jenga (Feat. Gaeko)          헤이즈 (Heize)
# 8        9            어린 왕자 (Prod. Godic)           김하온 (HAON)
# 9       10                      그때 헤어지면 돼                  로이킴
# 10      11                       HandClap  Fitz & The Tantrums
# 11      12                 Roller Coaster                   청하
# 12      13                BOOMERANG (부메랑)      Wanna One (워너원)
# 13      14                             선물                 멜로망스
# 14      15               소나기 (Feat. 10cm)                  용준형
# 15      16                        Bad Boy    Red Velvet (레드벨벳)
# 16      17                            You                 멜로망스
# 17      18      Havana (Feat. Young Thug)       Camila Cabello
# 18      19                         My Way         이수 (엠씨 더 맥스)
# 19      20        Like It (Feat. 행주, 보이비)      배연서 (WEBSTER B)
# 20      21                            비행운        문문 (MoonMoon)
# 21      22                  약속해요 (I.P.U.)      Wanna One (워너원)
# 22      23                        내가 더 나빠          헤이즈 (Heize)
# 23      24                            이 별                 길구봉구
# 24      25                      instagram                 DEAN
# 25      26                            눈사람                  정승환
# 26      27                         밤이 되니까           펀치 (Punch)
# 27      28                          가을 안부               먼데이 키즈
# 28      29                           #첫사랑               볼빨간사춘기
# 29      30                          벚꽃 엔딩              버스커 버스커
# 30      31                      Beautiful      Wanna One (워너원)
# 31      32                            주인공                   선미
# 32      33                 all of my life                   박원
# 33      34                    눈 떠보니 이별이더라                   포맨
# 34      35                   Heart Shaker         TWICE (트와이스)
# 35      36                   Shape of You           Ed Sheeran
# 36      37                             좋니                  윤종신
# 37      38     Young Wave (Feat. 행주, 보이비)    오담률 (CHIN CHILLA)
# 38      39               에너제틱 (Energetic)      Wanna One (워너원)
# 39      40                            밤편지                  아이유
# 40      41                            DNA                방탄소년단
# 41      42                          그리워하다                  비투비
# 42      43  시차 (We Are) (Feat. 로꼬 & GRAY)                  우원재
# 43      44                           괜찮냐고          헤이즈 (Heize)
# 44      45                             봄날                방탄소년단
# 45      46                          LIKEY         TWICE (트와이스)
# 46      47              빨간 맛 (Red Flavor)    Red Velvet (레드벨벳)
# 47      48                           지나오다            닐로 (Nilo)
# 48      49          비도 오고 그래서 (Feat. 신용재)          헤이즈 (Heize)
# 49      50                          매일 봐요                  마마무
#
#                                                Album
# 0                                  고등래퍼2 팀대항전 Part 3
# 1                                                꽃 길
# 2                                      Yellow Flower
# 3                                             Return
# 4                                  고등래퍼2 팀대항전 Part.1
# 5                                             GREAT!
# 6                                               그날처럼
# 7                                                 바람
# 8                                  고등래퍼2 팀대항전 Part.2
# 9                                          그때 헤어지면 돼
# 10                    Fitz and The Tantrums (Deluxe)
# 11                                            Offset
# 12                             0+1=1 (I PROMISE YOU)
# 13                                         Moonlight
# 14                                  소나기 (Feat. 10cm)
# 15  The Perfect Red Velvet - The 2nd Album Repackage
# 16                             투유 프로젝트 - 슈가맨2 Part.2
# 17                                            Camila
# 18                                     돈꽃 OST Part.1
# 19                                 고등래퍼2 팀대항전 Part.2
# 20                               LIFE IS BEAUTY FULL
# 21                             0+1=1 (I PROMISE YOU)
# 22                                                바람
# 23                                              Star
# 24                                         instagram
# 25                                             그리고 봄
# 26                                            밤이 되니까
# 27                                             가을 안부
# 28                                              #첫사랑
# 29                                        버스커 버스커 1집
# 30                       1-1=0 (NOTHING WITHOUT YOU)
# 31                                               주인공
# 32                                                0M
# 33                                       REMEMBER ME
# 34                                     Merry & Happy
# 35                                        ÷ (Deluxe)
# 36                                     LISTEN 010 좋니
# 37                                 고등래퍼2 팀대항전 Part 3
# 38                                  1X1=1(TO BE ONE)
# 39                                               밤편지
# 40                             LOVE YOURSELF 承 `Her`
# 41                                      Brother Act.
# 42                                       시차 (We Are)
# 43                                                바람
# 44                              YOU NEVER WALK ALONE
# 45                                       twicetagram
# 46                The Red Summer - Summer Mini Album
# 47                                         About You
# 48                                     /// (너 먹구름 비)
# 49                                 매일 봐요 (MAEIL BIO)

# %%
driver.get("http://www.melon.com/chart/day/index.htm#params%5Bidx%5D=51")

# %%
table_100 = driver.find_elements_by_css_selector("#tb_list tbody .lst100")

# %%
# get data of ranking 51~100
for table in table_100:
    
    rank = table.find_element_by_css_selector(".rank").text
    song = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank01 a").text
    artist = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank02 a").text
    album = table.find_element_by_css_selector(".wrap_song_info .ellipsis.rank03 a").text
    
    data = {"Ranking" : rank, 
            "Song" : song, 
            "Artist" : artist, 
            "Album" : album, }
    
    melon_100.loc[len(melon_100)] = data

# %%
melon_100 = melon_100.set_index('Ranking')

# %%
melon_100
# Out:
#                                           Song               Artist  \
# Ranking
# 1                       바코드 (Prod. GroovyRoom)           김하온 (HAON)
# 2                                          꽃 길              BIGBANG
# 3                                     별이 빛나는 밤                  마마무
# 4                       사랑을 했다 (LOVE SCENARIO)                 iKON
# 5                                북 (Prod. SLO)      배연서 (WEBSTER B)
# 6                                           뿜뿜      모모랜드 (MOMOLAND)
# 7                                         그날처럼                  장덕철
# 8                          Jenga (Feat. Gaeko)          헤이즈 (Heize)
# 9                          어린 왕자 (Prod. Godic)           김하온 (HAON)
# 10                                   그때 헤어지면 돼                  로이킴
# 11                                    HandClap  Fitz & The Tantrums
# 12                              Roller Coaster                   청하
# 13                             BOOMERANG (부메랑)      Wanna One (워너원)
# 14                                          선물                 멜로망스
# 15                            소나기 (Feat. 10cm)                  용준형
# 16                                     Bad Boy    Red Velvet (레드벨벳)
# 17                                         You                 멜로망스
# 18                   Havana (Feat. Young Thug)       Camila Cabello
# 19                                      My Way         이수 (엠씨 더 맥스)
# 20                     Like It (Feat. 행주, 보이비)      배연서 (WEBSTER B)
# 21                                         비행운        문문 (MoonMoon)
# 22                               약속해요 (I.P.U.)      Wanna One (워너원)
# 23                                     내가 더 나빠          헤이즈 (Heize)
# 24                                         이 별                 길구봉구
# 25                                   instagram                 DEAN
# 26                                         눈사람                  정승환
# 27                                      밤이 되니까           펀치 (Punch)
# 28                                       가을 안부               먼데이 키즈
# 29                                        #첫사랑               볼빨간사춘기
# 30                                       벚꽃 엔딩              버스커 버스커
# ...                                        ...                  ...
# 71                                     봄이 좋냐??                 10cm
# 72                                          답장                  김동률
# 73                               REALLY REALLY               WINNER
# 74                                      너의 이름을      Wanna One (워너원)
# 75                                      애쓰지 마요                  박보람
# 76                                    나의 사춘기에게               볼빨간사춘기
# 77                                    너 없는 시간들                  다비치
# 78                                         가시나                   선미
# 79                       Closer (Feat. Halsey)     The Chainsmokers
# 80                           Lonely (Feat. 태연)        종현 (JONGHYUN)
# 81                            연애소설 (Feat. 아이유)     에픽하이 (EPIK HIGH)
# 82                                          보여      Wanna One (워너원)
# 83                                     고민보다 Go                방탄소년단
# 84       모든 날, 모든 순간 (Every day, Every Moment)                   폴킴
# 85                              약속해요 (고백 Ver.)      Wanna One (워너원)
# 86                     운명 (The Chance of Love)         동방신기 (TVXQ!)
# 87                        팔레트 (Feat. G-DRAGON)                  아이유
# 88                                       헤어지래요                가비엔제이
# 89                           너랑나랑노랑 (Feat. 범키)                San E
# 90                                    Universe                  EXO
# 91                            나타나줘 (Feat. 박재범)                   로꼬
# 92                                      WE ARE      Wanna One (워너원)
# 93                                         넋두리            닐로 (Nilo)
# 94                                         고맙다                  세븐틴
# 95                                    MIC Drop                방탄소년단
# 96                                   별 바람 꽃 태양                  마마무
# 97                                        오늘밤도           펀치 (Punch)
# 98                                   Ko Ko Bop                  EXO
# 99                            Someone like you        EXO-CBX (첸백시)
# 100                                     피 땀 눈물                방탄소년단
#
#                                                      Album
# Ranking
# 1                                        고등래퍼2 팀대항전 Part 3
# 2                                                      꽃 길
# 3                                            Yellow Flower
# 4                                                   Return
# 5                                        고등래퍼2 팀대항전 Part.1
# 6                                                   GREAT!
# 7                                                     그날처럼
# 8                                                       바람
# 9                                        고등래퍼2 팀대항전 Part.2
# 10                                               그때 헤어지면 돼
# 11                          Fitz and The Tantrums (Deluxe)
# 12                                                  Offset
# 13                                   0+1=1 (I PROMISE YOU)
# 14                                               Moonlight
# 15                                        소나기 (Feat. 10cm)
# 16        The Perfect Red Velvet - The 2nd Album Repackage
# 17                                   투유 프로젝트 - 슈가맨2 Part.2
# 18                                                  Camila
# 19                                           돈꽃 OST Part.1
# 20                                       고등래퍼2 팀대항전 Part.2
# 21                                     LIFE IS BEAUTY FULL
# 22                                   0+1=1 (I PROMISE YOU)
# 23                                                      바람
# 24                                                    Star
# 25                                               instagram
# 26                                                   그리고 봄
# 27                                                  밤이 되니까
# 28                                                   가을 안부
# 29                                                    #첫사랑
# 30                                              버스커 버스커 1집
# ...                                                    ...
# 71                                                     3.2
# 72                                                      답장
# 73                                         FATE NUMBER FOR
# 74                                   0+1=1 (I PROMISE YOU)
# 75                                                  애쓰지 마요
# 76                                        Red Diary Page.1
# 77                                                     &10
# 78                             SUNMI SPECIAL EDITION `가시나`
# 79                                              Collage EP
# 80                                       종현 소품집 `이야기 Op.2`
# 81                          WE`VE DONE SOMETHING WONDERFUL
# 82                                   0+1=1 (I PROMISE YOU)
# 83                                   LOVE YOURSELF 承 `Her`
# 84                                 `키스 먼저 할까요?` OST Part.3
# 85                                   0+1=1 (I PROMISE YOU)
# 86       New Chapter #1 : The Chance of Love - The 8th ...
# 87                                                 Palette
# 88                                                   헤어지래요
# 89                                                  너랑나랑노랑
# 90                              Universe - 겨울 스페셜 앨범, 2017
# 91                                                    나타나줘
# 92                                   0+1=1 (I PROMISE YOU)
# 93                                                     넋두리
# 94                SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`
# 95                                   LOVE YOURSELF 承 `Her`
# 96                                           Yellow Flower
# 97                                                    오늘밤도
# 98                                 THE WAR - The 4th Album
# 99                                          라이브 OST Part.1
# 100                                                  WINGS
#
# [100 rows x 3 columns]

# %%
melon_100.to_csv('melon_chart_100')

# %%
driver.close()

# %%
melon_100 = pd.read_csv('melon_chart_100', index_col=0)
