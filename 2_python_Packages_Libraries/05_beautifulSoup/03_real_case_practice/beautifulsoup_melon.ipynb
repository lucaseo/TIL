# %%
import requests
import re
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://www.melon.com/chart/day/index.htm"

# %%
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;멜론 TOP 100&gt;일간&gt;&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="국내 최다 3,000만곡 보유, No.1 뮤직플랫폼 멜론! 실시간 차트부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="f13fc46b807bef984aa341efeb1adec8de12264c" name="naver-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="http://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/day/index.htm" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="/favicon.ico?2" id="favicon" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
# 		checkWin8Metro();
# 		function checkWin8Metro(){
# 			var userAgent = navigator.userAgent.toLowerCase();
# 			var canRunActiveX = false;
# 			try
# 			{
# 				canRunActiveX = !!new ActiveXObject("htmlfile");
# 			}
# 			catch (e)
# 			{
# 				canRunActiveX = false;
# 			}
# 			if ((userAgent.indexOf("windows nt 6.2") >= 0 || userAgent.indexOf("windows nt 6.3") >= 0 ) && userAgent.indexOf("msie") >= 0)
# 			{
# 				// windows 8
# 				if (canRunActiveX == false)
# 				{
# 					document.location.href = "http://t.melon.com";
# 				}
# 			}
# 		}
# 	</script>
# <link href="https://cdnimg.melon.co.kr/static/web/resource/style/w1/lp/y/169b3msqzz.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnimg.melon.co.kr/static/web/resource/style/w1/5r/m/14j3tr44urn.css" rel="stylesheet" type="text/css"/>
# <!-- 댓글 css 파일 네임 변경 -->
# <link href="https://cdnimg.melon.co.kr/static/web/resource/style/w1/qd/e/uolshpokn9.css" rel="stylesheet" type="text/css"/>
# <link href="/resource/style/web/chart/melonweb_chart_4x.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnimg.melon.co.kr/static/web/resource/style/w1/g6/0/kvg1wtiobj.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Nunito:400" rel="stylesheet"/>
# <script src="/resource/script/web/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="//member.melon.com/resource/script/web/member/melonweb_member_external.js?tm=20180115" type="text/javascript"></script>
# <script src="https://cdnimg.melon.co.kr/static/web/resource/script/w1/g8/u/kv5d3h4q8t.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#
# 	MelonPersonal.init();
#
# 	(function() {
# 		WEBPOCIMG = {
# 			defaultImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				var thumbType = "_500";
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
#
# 			defaultAlbumImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
#
# 			defaultArtistImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 300;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_300";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noArtist" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultDjImg : function(obj){
# 			},
# 			defaultMvImg : function(obj, width, height){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(height == null || height == '') height = $(obj).height();
#
# 				var ratio43 = Math.floor((4/3)*10)/10;
# 				var ratio169 = Math.floor((16/9)*10)/10;
# 				var ratioObj = Math.floor((width/height)*10)/10;
#
# 				var ratio = "4x3";
# 				if(ratioObj == ratio43){
# 					ratio = "4x3"; //contentsType = "mv43";
# 				} else if(ratioObj == ratio169){
# 					ratio = "16x9"; //contentsType = "mv169";
# 				} else {
# 					if(ratioObj > 1.5) ratio = "16x9";
# 					else ratio = "4x3";
# 				}
#
# 				if(width == 0) width = 640;
# 				if(height == 0) ratio = "16x9";
#
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_" + ratio + "_640";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noMovie" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultPlaylistImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultMemberImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 300;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_300";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noArtist" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultPhotoImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultShopImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 256;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_256";
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noProduct" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultShowwingImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
#
# 				var thumbType = "_256";
# 				if(width > 0 && width <= 300){
# 					thumbType = "_256";
# 				} else {
# 					thumbType = "_313";//추후 조절값
# 				}
# 				var altSrc = "http://cdnimg.melon.co.kr/resource/image/web/default/noShowing" + thumbType + ".jpg";
# 				if(obj.src != altSrc){
# 					obj.src = altSrc;
# 				}
# 			},
# 			defaultTicketImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
#
# 				var thumbType = "_256";
# 				if(width > 0 && width <= 300){
# 					thumbType = "_256";
# 				} else {
# 					thumbType = "_313";//추후 조절값
# 				}
# 				var altSrc = "http://cdnimg.melon.co.kr/resource/image/web/default/noTicket" + thumbType + ".png";
# 				if(obj.src != altSrc){
# 					obj.src = altSrc;
# 				}
# 			},
# 			defaultSmartRadioImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noSmartradio_59_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultConcertImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				var defaultImg = "http://cdnimg.melon.co.kr/resource/image/web/default/noAlbum_114_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			}
# 		}
# 		,WEBELLIPSIS = {
# 			ellipsis : function(ellipsisName,moreClassName,eWidth){
# 		        //아티스트 더보기
# 		        var arObj = $('.' + ellipsisName);
# 		        for(var i = 0; i < arObj.length; i++){
# 		            if (arObj.eq(i).width() > eWidth ){
# 		                arObj.eq(i).parent().parent().parent().find('.' + moreClassName).show();
# 		            }
# 		        }
# 			}
# 		}
# 	})();
# 	</script>
# </head>
# <body>
# <div id="wrap">
# <div id="skip_nav">skip navigation
# 		<ul>
# <li><a href="#gnb_menu">메뉴</a></li>
# <li><a href="#id_box">마이영역</a></li>
# <li><a href="#conts_section">본문</a></li>
# <li><a href="#footer">하단 정보</a></li>
# </ul>
# </div>
# <!--  header -->
# <div class="gnb2_expn" id="header">
# <div class="my_fold" id="header_wrap"> <!-- 1024이상 마이영역 접었을때 클래스 my_fold 추가 -->
# <div class="clfix" id="gnb">
# <!-- 상단 빠른 메뉴 -->
# <div id="util_menu">
# <p class="none">상단 빠른 메뉴</p>
# <div class="top_left">
# <ul class="clfix">
# <li class="first_child d_melon_ticket"><a class="menu01 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V08&amp;ACTION_AF_CLICK=V1" href="http://ticket.melon.com/main/index.htm" title="멜론 티켓"><span>멜론 티켓</span></a></li>
# <li><a class="menu03 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V05&amp;ACTION_AF_CLICK=V1" href="http://aztweb.melon.com/aztalk/guide/web/main.htm" title="멜론 아지톡"><span>멜론 아지톡</span></a></li><!-- 161206 -->
# </ul>
# </div>
# <!-- 140603_수정 -->
# <div class="top_right ">
# <ul class="clfix">
# <li class="first_child"><a class="menu01 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B01&amp;ACTION_AF_CLICK=V1" href="/commerce/pamphlet/web/sale_listMainView.htm" title="이용권구매"><span>이용권구매</span></a></li>
# <li><a class="menu02 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V06&amp;ACTION_AF_CLICK=V1" href="/event/vip/index.htm" title="VIP혜택관"><span>VIP혜택관</span></a></li>
# <li class="last_child"><a class="menu03 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B03&amp;ACTION_AF_CLICK=V1" href="/event/index.htm" title="이벤트"><span>이벤트</span></a></li>
# </ul>
# </div>
# <!-- //140603_수정 -->
# </div>
# <!-- //상단 빠른 메뉴 -->
# <!-- 140603_수정 -->
# <h1><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=M01&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/index.htm" title="MelOn 로고 - 홈으로 이동"><img alt="MelOn 로고 이미지" height="99" src="http://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" width="142"/></a></h1>
# <!-- //140603_수정 -->
# <!-- 통합검색 영역 -->
# <fieldset>
# <legend>통합검색영역</legend>
# <input id="top_search" name="" onkeypress="if(event.keyCode == 13){goSearch();}" placeholder="" style="width:249px" title="검색 입력 편집창" type="text"/><input id="keywordLink" name="keywordLink" type="hidden" value=""/>
# <button class="btn_icon btn_auto close" id="top_search_autocomplete_toggle" style="display: none;" title="자동검색 펼침" type="button"><span class="odd_span">자동검색 펼침</span></button> <!-- open/close 클래스 사용 -->
# <button class="btn_icon search_m" title="검색" type="button"><span class="odd_span">검색</span></button>
# <div class="auto_complete" id="top_search_autocomplete"><div class="auto_complete_cont" style="display:block;"><!-- 자동완성 레이어 --></div></div>
# <div class="auto_complete" id="top_search_autocomplete_template" style="display: none;"> <!-- 자동완성 레이어 템플릿 -->
# <!-- 텍스트 결과 -->
# <ul class="text_result">
# <li><a class="autocomplete-label" href="#"></a></li>
# </ul>
# <!-- 섬네일 결과 -->
# <ul class="thumb_result">
# <li class="cate"></li>
# <li class="class02">
# <a href="#">
# <span class="thumb_40">
# <span class="thumb_frame"></span>
# <img alt="" class="autocomplete-img" height="40" width="40"/>
# </span>
# <div class="info">
# <span class="autocomplete-label"></span><br/>
# <span><span class="f11 autocomplete-info"></span></span>
# </div>
# </a>
# </li>
# </ul>
# <!-- 검색어가 없을 때 -->
# <ul class="text_result">
# <li class="result_none">
# <span>해당글자로 시작하는 단어가 없습니다.</span>
# </li>
# </ul>
# </div>
# </fieldset>
# <form action="" id="searchFrm" method="get" style="display: none">
# <input name="q" type="hidden"/>
# <input name="section" type="hidden"/>
# </form>
# <!-- //통합검색 영역 -->
# <!-- 실시간 검색어 -->
# <div class="realtime_soar_keyword">
# <!-- 140519_수정 -->
# <a class="title" href="http://www.melon.com/search/trend/index.htm">급상승 키워드</a>
# <!-- //140519_수정 -->
# <div class="keyword_overlay">
# <ol style="overflow:hidden; height:20px;">
# <!-- 롤링 영역
# 							<li>
# 								<div style="top:;">
# 									<strong class="order bg2 on"><span class="none">1 위</span></strong>
# 									<a href="#" class="ellipsis" title="something">something</a>
# 									<span class="wrap_rank">
# 										<span class="icon_up">순위상승수</span><span>139</span>
# 										<!- <span class="icon_rank_new">새진입</span>
# 									</span>
# 								</div>
# 							</li>
# 							//롤링 영역 -->
# </ol>
# <!-- 140423_추가 -->
# <a class="keyword_more" href="http://www.melon.com/search/trend/index.htm" title="실시간 순위"><span>더보기 <span></span></span></a>
# <!-- //140423_추가 -->
# </div>
# <!-- 140423_삭제 -->
# <!-- <a href="#" class="d_btn_ctrl pause" title="이벤트 일시정지"><span><span class="none">일시정지</span></span></a> -->
# <!-- //140423_삭제 -->
# </div>
# <!-- //실시간 검색어 -->
# <!-- 배너 영역 -->
# <div class="cmn_banner"></div>
# <script type="text/javascript">
# 				MelonPersonal.printLayout();
# 				</script>
# </div>
# <!-- 140314_gnb마크업 수정 -->
# <div id="gnb_menu">
# <ul>
# <li class="nth1 on">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=R01&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/chart/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu01">멜론차트</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child on"><a href="http://www.melon.com/chart/index.htm"><span class="menu_chart m1">멜론 TOP 100</span></a></li>
# <li class=""><a href="http://www.melon.com/melonaward/timeline.htm?f=c"><span class="menu_chart m2">주간 인기상</span></a></li>
# <li class=""><a href="http://www.melon.com/chart/vdo/index.htm"><span class="menu_chart m3">트렌드 차트</span></a></li>
# <li class=""><a href="http://www.melon.com/chart/genre/index.htm"><span class="menu_chart m4">장르 스타일 차트</span></a></li>
# <li class=""><a href="http://www.melon.com/chart/age/index.htm"><span class="menu_chart m5">시대별 차트</span></a></li>
# </ul>
# <div class="chart_finder">
# <button class="btn_chart_f" onclick="location.href='http://www.melon.com/chart/search/index.htm'" type="button"><span class="odd_span">차트 파인더</span></button>
# </div>
# </div>
# </li>
# <li class="nth2">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C01&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/new/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu02 ">최신</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="http://www.melon.com/new/index.htm"><span class="menu_new m1">최신곡</span></a></li>
# <li class=""><a href="http://www.melon.com/new/album/index.htm"><span class="menu_new m2">최신앨범</span></a></li>
# <li class=""><a href="http://www.melon.com/new/mv/index.htm"><span class="menu_new m3">최신 뮤직비디오</span></a></li>
# <!-- 160404 제거 -->
# <!-- // 160404 제거 -->
# </ul>
# </div>
# </li>
# <li class="nth3">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C03&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/genre/song_list.htm?gnrCode=GN0100"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu03">장르</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="http://www.melon.com/genre/song_list.htm?gnrCode=GN0100"><span class="menu_gnr nm1">한국대중음악</span></a></li>
# <li class=""><a href="http://www.melon.com/genre/song_list.htm?gnrCode=GN0900"><span class="menu_gnr nm2">해외POP음악</span></a></li>
# <li class=""><a href="http://www.melon.com/genre/song_list.htm?gnrCode=GN1500"><span class="menu_gnr nm3">그외 인기장르</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth4">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S04&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/dj/today/djtoday_list.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu04">멜론DJ</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="http://www.melon.com/dj/today/djtoday_list.htm"><span class="menu_dj m1">오늘은 뭘 듣지</span></a></li>
# <li class=""><a href="http://www.melon.com/dj/essential/djessential_list.htm"><span class="menu_dj m2">전문가 선곡</span></a></li>
# <li class=""><a href="http://www.melon.com/dj/themegenre/djthemegenre_list.htm"><span class="menu_dj m3">#테마장르</span></a></li>
# <li class=""><a href="http://www.melon.com/dj/powerdj/djpowerdj_list.htm"><span class="menu_dj m4">파워DJ</span></a></li>
# <li class=""><a href="http://www.melon.com/dj/chart/djchart_list.htm"><span class="menu_dj m5">인기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth5">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S05&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/tv/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu05">멜론TV</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="http://www.melon.com/tv/index.htm"><span class="menu_tv m1">오늘은 뭘 볼까</span></a></li>
# <li class=""><a href="http://www.melon.com/tv/mv/index.htm"><span class="menu_tv m2">뮤직비디오</span></a></li>
# <li class=""><a href="http://www.melon.com/tv/menu/index.htm?menuSeq=1"><span class="menu_tv m3">멜론 오리지널</span></a></li>
# <li class=""><a href="http://www.melon.com/tv/menu/index.htm?menuSeq=4"><span class="menu_tv m4">아티스트 업데이트</span></a></li>
# <li class=""><a href="http://www.melon.com/tv/menu/index.htm?menuSeq=3"><span class="menu_tv m5">방송</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth6">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S07&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/artistplus/todayupdate/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu06">스타포스트</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="http://www.melon.com/artistplus/todayupdate/index.htm"><span class="menu_arti m1">NOW</span></a></li>
# <li class=""><a href="http://www.melon.com/artistplus/themespecial/index.htm"><span class="menu_arti m2">테마스페셜</span></a></li>
# <li class=""><a href="http://www.melon.com/artistplus/artistchart/index.htm"><span class="menu_arti m3">아티스트 랭킹</span></a></li>
# <li class=""><a href="http://www.melon.com/artistplus/myranking/index.htm"><span class="menu_arti m4">마이 랭킹</span></a></li>
# </ul>
# <div class="menu_artist_btn">
# <div class="artist_fan">
# <button class="btn_fan" onclick="MELON.WEBSVC.POC.menu.goMyMusicFanSignArtist();" type="button"><span class="odd_span">팬맺은 아티스트</span></button>
# </div>
# <div class="artist_finder">
# <button class="btn_artist_f" onclick="location.href='http://www.melon.com/artistplus/finder/index.htm'" type="button"><span class="odd_span">아티스트 파인더</span></button>
# </div>
# </div>
# </div>
# </li>
# <!-- 160314 수정 -->
# <li class="nth7">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S09&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/musicstory/today/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu07">멜론매거진</span></a>
# </li>
# <!-- // 160314 수정 -->
# <li class="nth8">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S11&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/melonaward/timeline.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu08">뮤직어워드</span></a>
# </li>
# <!-- 170531 수정 kjh -->
# <li class="nth10">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C05&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/flac/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu12">멜론Hi-Fi</span><span class="icon_new"></span></a>
# </li>
# <!-- //170531 수정 kjh -->
# <li class="nth9 last_child">
# <!-- //140523_수정 -->
# <a class="cur_menu mlog_without_page_change" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S99&amp;ACTION_AF_CLICK=V1" href="#"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu09">더보기</span></a>
# <div class="more_wrap" style="display:none"><!-- more_lay일때 display:block -->
# <ul>
# <li class="first_child"><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S06&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/smartradio/index.htm"><span class="menu_more m1">스마트라디오</span></a></li>
# <li class=""><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C04&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/edu/index.htm"><span class="menu_more m3">어학</span></a></li>
# <li class=""><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V02&amp;ACTION_AF_CLICK=V1" href="http://www.melon.com/customer/announce/index.htm"><span class="menu_more m4">공지사항</span></a></li>
# </ul>
# </div>
# </li>
# </ul>
# <ul class="sub_gnb">
# <li class="">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S01&amp;ACTION_AF_CLICK=V1" href="javascript:MELON.WEBSVC.POC.menu.goMyMusicMain();"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu10">마이뮤직</span></a>
# </li>
# <li>
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S02&amp;ACTION_AF_CLICK=V1" href="javascript:MELON.WEBSVC.POC.menu.goFeed();"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu11">피드</span><span class="msg_box" style="display: none;"><span class="num">99+</span><span class="none">개</span></span></a>
# </li>
# </ul>
# </div>
# <!-- location 기획 요청으로 제거 2014-04-01 -->
# <!-- //location -->
# </div>
# </div>
# <!-- //header -->
# <div class="clfix" id="cont_wrap">
# <div class="my_fold" id="conts_section">
# <!-- contents -->
# <!-- contents -->
# <div id="conts">
# <div class="page_header">
# <h2 class="title">멜론 TOP100</h2>
# <div class="tooltip">
# <button class="button_icons etc tooltip" data-control="dropdown" type="button"><span class="none">툴팁보기</span></button>
# <div class="layer_popup" role="dialog">
# <p class="desc">일간 서비스 이용량 중 스트리밍 40%+다운로드 60%를 반영한 차트입니다.</p>
# <button class="button_icons etc close d_close" type="button"><span class="none">닫기</span></button>
# </div>
# </div>
# </div>
# <div class="wrap_tabmenu01">
# <ul>
# <li class="first_child"><a class="link_tab" href="/chart/index.htm"><span class="cntt">실시간</span></a></li>
# <li><a class="link_tab" href="/chart/rise/index.htm" title="급상승 차트 - 페이지 이동"><span class="cntt">급상승</span></a></li>
# <li class="on"><a class="link_tab" href="/chart/day/index.htm" title="일간 차트 - 페이지 이동"><span class="cntt">일간</span></a></li>
# <li><a class="link_tab" href="/chart/week/index.htm" title="주간 차트 - 페이지 이동"><span class="cntt">주간</span></a></li>
# <li class="last_child"><a class="link_tab" href="/chart/month/index.htm" title="월간 차트 - 페이지 이동"><span class="cntt">월간</span></a></li>
# </ul>
# </div>
# <div class="wrap_tabmenu_sub">
# <dl>
# <dt>종합</dt>
# <dd>
# <ul>
# <li class="first_child" id="GN0000"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0000"><span class="cntt">장르종합</span></a></li>
# <li id="DM0000"><a class="link_tab" href="/chart/day/index.htm?classCd=DM0000"><span class="cntt">국내종합</span></a></li>
# <li class="last_child" id="AB0000"><a class="link_tab" href="/chart/day/index.htm?classCd=AB0000"><span class="cntt">해외종합</span></a></li>
# </ul>
# </dd>
# <dt>한국대중음악</dt>
# <dd>
# <ul>
# <li class="first_child" id="GN0100"> <a class="link_tab" href="/chart/day/index.htm?classCd=GN0100"><span class="cntt">발라드</span></a></li>
# <li id="GN0200"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0200"><span class="cntt">댄스</span></a></li>
# <li id="GN0300"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0300"><span class="cntt">랩/힙합</span></a></li>
# <li id="GN0400"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0400"><span class="cntt">R&amp;B/Soul</span></a></li>
# <li id="GN0500"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0500"><span class="cntt">인디음악</span></a></li>
# <li id="GN0600"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0600"><span class="cntt">록/메탈</span></a></li>
# <li id="GN0700"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0700"><span class="cntt">트로트</span></a></li>
# <li class="last_child" id="GN0800"> <a class="link_tab" href="/chart/day/index.htm?classCd=GN0800"><span class="cntt">포크/블루스</span></a></li>
# </ul>
# </dd>
# <dt>해외POP음악</dt>
# <dd>
# <ul>
# <li class="first_child" id="GN0900"><a class="link_tab" href="/chart/day/index.htm?classCd=GN0900"><span class="cntt">POP</span></a></li>
# <li id="GN1000"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1000"><span class="cntt">록/메탈</span></a></li>
# <li id="GN1100"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1100"><span class="cntt">일렉트로니카</span></a></li>
# <li id="GN1200"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1200"><span class="cntt">랩/힙합</span></a></li>
# <li id="GN1300"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1300"><span class="cntt">R&amp;B/Soul</span></a></li>
# <li class="last_child" id="GN1400"> <a class="link_tab" href="/chart/day/index.htm?classCd=GN1400"><span class="cntt">포크/블루스/컨트리</span></a></li>
# </ul>
# </dd>
# <dt>그외인기장르</dt>
# <dd>
# <ul>
# <li class="first_child" id="GN1500"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1500"><span class="cntt">OST</span></a></li>
# <li id="GN1700"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1700"><span class="cntt">재즈</span></a></li>
# <li id="GN1800"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1800"><span class="cntt">뉴에이지</span></a></li>
# <li id="GN1900"><a class="link_tab" href="/chart/day/index.htm?classCd=GN1900"><span class="cntt">J-pop</span></a></li>
# <li id="GN2000"><a class="link_tab" href="/chart/day/index.htm?classCd=GN2000"><span class="cntt">월드뮤직</span></a></li>
# <li id="GN2100"><a class="link_tab" href="/chart/day/index.htm?classCd=GN2100"><span class="cntt">CCM</span></a></li>
# <li id="GN2200"><a class="link_tab" href="/chart/day/index.htm?classCd=GN2200"><span class="cntt">어린이/태교</span></a></li>
# <li id="GN2300"><a class="link_tab" href="/chart/day/index.htm?classCd=GN2300"><span class="cntt">종교음악</span></a></li>
# <li class="last_child" id="GN2400"> <a class="link_tab" href="/chart/day/index.htm?classCd=GN2400"><span class="cntt">국악</span></a></li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="calendar_prid">
# <span class="yyyymmdd">
# <span class="year">2018.03.02</span>
# </span>
# <span class="hhmm">
# <span class="hour">장르종합</span>
# </span>
# </div>
# <!-- 일간 TOP 100 목록 -->
# <div id="tb_list" style="display: none">
# <form id="frm" name="frm">
# <div class="service_list_song type02 d_song_list">
# <h3 class="none"></h3>
# <!-- 곡리스트 테이블 -->
# <div class="wrap_btn_tb top">
# <button class="button_rbox" onclick="playChart();" title="TOP 100 듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt"><span class="eng">TOP100</span> 듣기</span></button>
# <button class="button_rbox" onclick="melon.play.playFormSong('19041201','frm');" title="선택된 곡 듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">듣기</span></button>
# <button class="button_rbox" onclick="melon.play.addFormPlayList('frm');" title="선택된 곡 담기" type="button"><span class="button_icons type02 scrap"></span><span class="cnt">담기</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','0','');" title="선택된 곡 다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt">다운</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','110','19041201');" title="선택된 곡 원음다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt"><span class="eng">FLAC</span></span></button>
# <button class="button_rbox" onclick="melon.buy.goPresent('song', 'frm', '19041201');" title="선택된 곡 선물하기" type="button"><span class="button_icons type02 gift"></span><span class="cnt">선물</span></button>
# </div>
# <table border="1" style="width:100%">
# <caption>이 표는 곡 리스트로 체크박스, 순위, 곡정보, 좋아요, 뮤비, 다운, 폰전송 내용을 포함하고 있으며 표 상 하단에 제공하는 전체선택, 듣기, 다운로드, 담기, 선물하기 기능을 이용하실 수 있습니다.</caption>
# <colgroup>
# <col style="width: 15px"/><!-- checkbox -->
# <col style="width: 62px"/><!-- 순서 & 순위 -->
# <col style="width: 50px"/><!-- 순위등락 -->
# <col style="width: 60px"/><!-- 앨범이미지 -->
# <col style="width: 24px"/><!-- 곡 상세가기 -->
# <col/><!-- 곡정보 -->
# <col style="width: 190px"/><!-- 앨범 -->
# <col style="width: 135px"/><!-- 좋아요 -->
# <col style="width: 45px"/><!-- 듣기 -->
# <col style="width: 52px"/><!-- 담기 -->
# <col style="width: 52px"/><!-- 다운 -->
# <col style="width: 52px"/><!-- 뮤비 -->
# <col style="width: 52px"/><!-- 링/벨 -->
# </colgroup>
# <thead>
# <tr>
# <th scope="col">
# <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
# </th>
# <th scope="col">
# <div class="wrap t_center"><span class="rank">순위</span></div>
# </th>
# <th scope="col">
# <div class="wrap none">순위등락</div>
# </th>
# <th scope="col">
# <div class="wrap none">앨범이미지</div>
# </th>
# <th scope="col">
# <div class="wrap none">곡 상세가기</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">곡정보</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">앨범</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_30">좋아요</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">듣기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">담기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">다운</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">뮤비</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">링/벨</div>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr class="lst50" data-song-no="30859584" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="사랑을 했다 (LOVE SCENARIO) 곡 선택" type="checkbox" value="30859584"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10132945');" title="Return">
# <img alt="Return - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/32/945/10132945_500.jpg/melon/resize/120/quality/80/optimize" width="60">
# <span class="bg_album_frame"></span>
# </img></a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30859584');" title="사랑을 했다 (LOVE SCENARIO) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30859584);" title="사랑을 했다 (LOVE SCENARIO) 재생">사랑을 했다 (LOVE SCENARIO)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10132945');" title="Return - 페이지 이동">Return</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30859584" title="사랑을 했다 (LOVE SCENARIO) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30859584);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30859584');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30859584', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30859584','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30859584')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30816860" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="뿜뿜 곡 선택" type="checkbox" value="30816860"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">2</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT!">
# <img alt="GREAT! - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/24/822/10124822_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30816860');" title="뿜뿜 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30816860);" title="뿜뿜 재생">뿜뿜</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT! - 페이지 이동">GREAT!</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30816860" title="뿜뿜 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30816860);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30816860');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30816860', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30816860','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30816860')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30755375" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="그날처럼 곡 선택" type="checkbox" value="30755375"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">3</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼">
# <img alt="그날처럼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/15/186/10115186_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30755375');" title="그날처럼 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30755375);" title="그날처럼 재생">그날처럼</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼 - 페이지 이동">그날처럼</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30755375" title="그날처럼 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30755375);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30755375');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30755375', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30755375','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30755375')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30884950" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="그때 헤어지면 돼 곡 선택" type="checkbox" value="30884950"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">4</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼">
# <img alt="그때 헤어지면 돼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/37/574/10137574_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30884950');" title="그때 헤어지면 돼 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30884950);" title="그때 헤어지면 돼 재생">그때 헤어지면 돼</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼 - 페이지 이동">그때 헤어지면 돼</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30884950" title="그때 헤어지면 돼 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30884950);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30884950');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30884950', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30884950','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30884950')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30864993" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Bad Boy 곡 선택" type="checkbox" value="30864993"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">5</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage">
# <img alt="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/34/032/10134032_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30864993');" title="Bad Boy 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30864993);" title="Bad Boy 재생">Bad Boy</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동">The Perfect Red Velvet - The 2nd Album Repackage</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30864993" title="Bad Boy 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30864993);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30864993');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30864993', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30864993','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30864993')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30567963" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Havana (Feat. Young Thug) 곡 선택" type="checkbox" value="30567963"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">6</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila">
# <img alt="Camila - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/85/877/10085877_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30567963');" title="Havana (Feat. Young Thug) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30567963);" title="Havana (Feat. Young Thug) 재생">Havana (Feat. Young Thug)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila - 페이지 이동">Camila</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30567963" title="Havana (Feat. Young Thug) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# ...
# 						params.idx = 1;
# 						$('.lst100 > td').hide();
# 						$('.lst100').hide();
# 						$('.lst50').show();
# 						$('.lst50 > td').show();
# 						$('.page_num').html("<strong>1 - 50위</strong><i class=\"bar\"></i><a href=\"javascript:movePage(2);\" title=\"51 - 100 위 - 페이지 이동\">51 - 100위</a>");
#
# 					} else if (v == 2) {
# 						params.idx = 51;
# 						$('.lst50 > td').hide();
# 						$('.lst50').hide();
# 						$('.lst100').show();
# 						$('.lst100 > td').show();
# 						$('.page_num').html("<a href=\"javascript:movePage(1);\" title=\"51 - 100 위 - 페이지 이동\">1 - 50위</a><i class=\"bar\"></i><strong>51 - 100위</strong>");
# 					}
# 					if (typeof $.bbq != 'undefined' && v != 0) {
# 						$.bbq.pushState({params:params});
# 					} else {
# 						ajxm = false;
# 					}
# 					WEBELLIPSIS.ellipsis("checkEllipsis","wrap_atist",240);
#
# 					$('.input_check').checked(false);
# 					//$('.input_check').each(function() {
# 					//});
# 					$(window).scrollTop(0);
# 				}
#
# 				$(function(){
# 					/* 멜론 차트 곡만 듣기 */
# 					playChart = function() {
# 						var songList = $('tr').map(function() { return $(this).attr('data-song-no'); }).get();
# 						melon.play.playSong('19041201', songList);
# 					}
# 					/* 리스트 다중 선택 */
# 					$('.input_check').optShift();
# 					/* 페이징 노출*/
# 					$('.chart_page').css({'display':''});
#
# 				});
# 			</script>
# </div>
# <!-- //일간 TOP 100 목록 -->
# </div>
# <!-- //contents -->
# <script type="text/javascript">
# 		var httpWww = "http://www.melon.com";
# 		var httpsWww = "https://www.melon.com";
# 		var POC_ID = "XXXX";
# 	</script>
# <script src="/resource/script/web/common/melonweb_openlib.js" type="text/javascript"></script>
# <script src="https://cdnimg.melon.co.kr/static/web/resource/script/w1/tu/7/15u99gmdn3.js" type="text/javascript"></script>
# <script src="https://cdnimg.melon.co.kr/static/web/resource/script/w1/og/7/kv18j7iqi3.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/MPAPI.js?tm=20171129" type="text/javascript"></script>
# <script src="https://cdnimg.melon.co.kr/static/web/resource/script/w1/fn/n/1y0yzmf9x67.js" type="text/javascript"></script>
# <script src="https://cdnimg.melon.co.kr/static/web/resource/script/w1/jd/v/14ifiepkjxj.js" type="text/javascript"></script>
# <script src="/resource/script/web/chart/json2.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/melonweb_zam.js?tm=2016042816" type="text/javascript"></script>
# <script src="https://cdnimg.melon.co.kr/static/web/resource/script/w1/8k/8/1ed5h822hvv.js" type="text/javascript"></script>
# <script src="https://log.melon.com/mlog.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		var melon = MELON.WEBSVC.POC;
#
# 		document.domain="melon.com";
#
# 		//pocId 쿠키설정 실행
# 		try {
# 			melon.setPocId();
# 		} catch (e){}
# 	</script>
# <script src="/resource/script/web/common/socket.io.js" type="text/javascript"></script>
# <script src="/resource/script/web/chart/melonweb_chart.js" type="text/javascript"></script>
# <script src="/resource/script/common/jquery.ba-bbq.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# var curUrl=location.href;
# var ajxm=false;
# $(window).bind('hashchange', function(e) {
# 	if ( typeof e.getState('params') === 'undefined' ) {
# 		movePage(0);
# 	} else {
# 		if (ajxm) { ajxm=false; return; }
# 		var p = e.getState('params');
# 		movePage( p.idx == 1 ? 1 : 2 );
# 		ajxm=false;
# 	}
# 	$("#tb_list").css({'display':''});
# });
# $(document).ready(function(){$(window).trigger('hashchange');});
# $('#GN0000').addClass("on");
# </script>
# <!-- //contents -->
# </div>
# </div>
# <!-- footer -->
# <div class="my_fold" id="footer">
# <div class="btn_top_wrap">
# <a class="btn_top" href="#skip_nav" style="" title="맨 위로 가기"><span>맨 위로 가기</span></a>
# </div>
# <div class="wrap_pop_notice" id="popNotice">
# <div class="pop_notice_inner">
# <div class="bd">
# <h1>웹 브라우저 보안 암호화 <br>알고리즘 업그레이드 안내</br></h1>
# <div class="wrap_notice">
# <div class="info_cont">
# <div class="txt01">
# <p>안녕하세요. 보안 암호화 알고리즘 업그레이드 관련 멜론에서 알려드립니다. <br>지금 이용하고 계신 OS와 브라우저는 새로운 보안 암호화 알고리즘을 지원하<br>지 못하여 이용이 제한 될 수 있습니다</br></br></p>
# <p class="pgh">현재 적용된 SHA-1 보안 암호화 알고리즘은 데이터 위조공격 가능성이 있어 <br>주요 브라우저들의 지원 중단이 예정되어있습니다. <br>멜론에서도 회원 분들의 좀 더 안전한 서비스 이용을 보장하기 위해 보안 암호<br>화 알고리즘 업그레이드를 진행 할 예정입니다.</br></br></br></p>
# </div>
# <div class="txt02">
# <p>업그레이드 내용 : SHA-1 방식 → SHA-2 방식으로 업그레이드 </p>
# <p class="date">적용일: <span>2016년 12월 23일</span></p>
# </div>
# </div>
# <div class="info_cont cont2">
# <div class="txt01">
# <p>보안 암호화 알고리즘 업그레이드에 따라 SHA-2 방식을 지원하지 않는 OS나 <br>브라우저를 이용하시면 멜론서비스 이용에 제한이 있을 수 있습니다. <br>아래 지원 가능한 OS 또는 브라우저를 확인하시고 회원 분들께서는 업데이트 <br> 후 이용해주시기 바랍니다.</br></br></br></p>
# </div>
# <div class="txt02">
# <dl>
# <dt>SHA-2 지원 OS / 브라우저</dt>
# <dd>
# <p>OS</p>
# <ul>
# <li>Windows XP SP3 이상</li>
# <li>Mac OS X 10.5 이상</li>
# </ul>
# </dd>
# <dd class="list">
# <p>브라우저</p>
# <ul>
# <li>Internet Explorer 버전 7 이상</li>
# <li>Chrome 버전 26 이상</li>
# <li>FireFox: 버전 1.5 이상</li>
# <li>Safari: 버전 3 이상 (Mac OS X 10.5 이상)</li>
# <li>Opera: 버전 7 이상</li>
# </ul>
# </dd>
# </dl>
# <p class="refer">* 멜론서비스는 공식적으로 IE8이상 지원하며, Opera는 미지원함을 참고 부탁드립니다.</p>
# </div>
# <div class="txt03">
# <p>앞으로도 좋은 서비스와 안정성으로 보답할 수 있도록 최선을 다하겠습니다. <br>감사합니다.</br></p>
# </div>
# </div>
# </div>
# <div class="wrap_input_box">
# <div class="check_area d_check_on">
# <input data-cookie-id="popNotice" id="todayChk" type="checkbox">
# <label for="todayChk">오늘하루 보지 않기</label>
# </input></div>
# <div class="btn-area">
# <button class="d_close" type="button"><span>확인</span></button>
# </div>
# </div>
# </div>
# </div>
# <span class="shadow"></span>
# </div>
# <div class="footer_cont">
# <div class="footer_menu">
# <!-- 				<ul class="fl_left"> -->
# <!-- 					<li class="menu01 d_melon_ticket"><a href="http://ticket.melon.com/main/index.htm"><span>MelOn Ticket</span></a></li> -->
# <!-- 					<li class="menu04"><a href="http://aztweb.melon.com/aztalk/guide/web/main.htm"><span>aztalk</span></a></li> -->
# <!-- 				</ul> -->
# <ul class="fl_right">
# <li class="menu05"><a href="http://www.melon.com/serviceintro/index.htm"><span>멜론4.0 둘러보기</span></a></li><!-- 160824 수정 -->
# <li class="menu06"><a href="http://www.melon.com/customer/serviceintro/index.htm"><span>Windows 플레이어</span></a></li><!-- 160824 수정 -->
# <li class="menu07"><a href="http://www.melon.com/customer/serviceintro/multi_pc_web.htm"><span>Mac 플레이어</span></a></li>
# <li class="menu09"><a href="http://www.melon.com/customer/serviceintro/ipad.htm"><span>iPad</span><span class="icon_new"></span></a></li>
# <li class="menu08"><a href="http://faqs2.melon.com/customer/index.htm"><span>고객센터</span></a></li>
# </ul>
# </div>
# <ul class="footer_policy clfix">
# <li class="first_child"><a href="http://www.iloen.com/" target="_blank" title="회사소개 ">회사소개</a></li>
# <li><a href="http://info.melon.com/terms/web/terms1_1.html" target="_blank" title="이용약관 ">이용약관</a></li>
# <li><a href="http://info.melon.com/terms/web/terms3.html" target="_blank" title="개인정보처리방침 "><strong>개인정보처리방침</strong></a></li>
# <li><a href="http://info.melon.com/terms/web/terms5_1.html" target="_blank" title="청소년보호정책">청소년보호정책</a></li>
# <li><a href="http://faqs2.melon.com/customer/faq/informFaq.htm?no=1&amp;faqId=QUES20140616000001&amp;SEARCH_KEY=&amp;SEARCH_PAR_CATEGORY=CATE20130909000006&amp;SEARCH_CATEGORY=CATE20130909000021" title="제휴/프로모션문의">제휴/프로모션문의</a></li>
# <li><a href="javascript:openEmailCollectionReject();" title="이메일주소무단수집거부 ">이메일주소무단수집거부</a></li>
# <li><a href="https://partner.melon.com/partrct/login/web/login_loginProcess.htm?t=s" target="_blank" title="파트너센터">파트너센터</a></li>
# <li class="last_child"><a href="http://www.ftc.go.kr/info/bizinfo/communicationView.jsp?apv_perm_no=2011322016230202008&amp;area1=&amp;area2=&amp;currpage=2&amp;searchKey=01&amp;searchVal=로엔&amp;stdate=&amp;endate=" title="사업자정보확인">사업자정보확인</a></li><!-- 160629 추가 -->
# </ul>
# <!--160531 수정 lyr-->
# <p>
# <span class="first">서울시 강남구 테헤란로 103길 17</span><span>대표이사 : 박성훈</span><span>사업자등록번호 : 138-81-05876</span><span>통신판매업 신고번호 : 제2011-서울강남-02008호</span><br><span class="first">문의전화(평일 09:00~18:00) : 1566-7727 (유료)</span><span>이메일 : <a class="btn_footer_mail" href="https://help.melon.com/web/customer/help/helpForm.htm?type=" target="_blank">meloninformation@iloen.com</a></span><span>© 2016. LOEN Entertainment, Inc. ALL RIGHTS RESERVED.</span>
# </br></p>
# <!--//160531 수정 lyr-->
# <!--161209 수정 lyr-->
# <div class="ban">
# <!-- 180129 수정 sally -->
# <a href="http://www.melon.com/footer/awrad.htm?pageType=02"><img alt="2018 대한민국 퍼스트브랜드 대상" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer01_20180125.png" width="100"/></a>
# <a href="http://www.melon.com/footer/awrad.htm?pageType=04"><img alt="2018 소비자가 뽑은 가장 신뢰하는 브랜드 대상" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer04_20180125.png" width="125"/></a>
# <!-- //180129 수정 sally -->
# <a href="http://www.melon.com/footer/awrad.htm?pageType=03"><img alt="한국능률협회컨설팅 2017 브랜드 파워 1위" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer02_170308.png" width="113"/></a>
# <a href="http://www.melon.com/footer/awrad.htm?pageType=05"><img alt="2016 대한민국 브랜드 고객충성도 1위" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer10.png" width="118"/></a>
# <a href="http://www.kdce.or.kr/user/ctf/clmsCtfTransList.do?NmberBusiRegNo=1388105876&amp;websiteName=www.melon.com&amp;SUB=FB" target="_blank"><img alt="음악저작권 이용허락 인증" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer06_161209.png" width="82"/></a>
# <a href="http://www.cleansite.org/" target="_blank"><img alt="클린사이트" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer07_161209.png" width="70"/></a>
# <a class="last_child" href="http://isms.kisa.or.kr/" target="_blank"><img alt="정보보호 관리체계 ISMS 인증" height="25" src="http://cdnimg.melon.co.kr/resource/image/web/common/ban_footer09_161209.png" width="102"/></a>
# </div>
# <!--//161209 수정 lyr-->
# <!--모바일 웹 버전, 태블릿에서만 적용됨. display none, block 으로 적용-->
# <!--140602 추가 lyr-->
# <div class="mobile_btn_wrap" style="display:none;">
# <p>접속하신 단말/브라우저에서는 멜론 서비스의 사용이 일부 제한될 수 있습니다. 양해부탁드립니다.</p>
# <a class="btn" href="#" title="모바일 웹 버전">
# <span class="odd_span">
# <span class="even_span">모바일 웹 버전</span>
# </span>
# </a>
# </div>
# <!--//140602 추가 lyr-->
# </div>
# <a class="btn_top" href="#" style="display: none;" title="맨 위로 가기">맨 위로 가기</a>
# <script type="text/javascript">
#
# 			$(function() {
# 				//favicon 분기 처리
# 				var pocId = MELON.WEBSVC.POC.getPocId();
# 				if('AS20' == pocId || 'HT10' == pocId){
# 					$('link#favicon').attr('href','http://cdnimg.melon.co.kr/resource/mobile40/cds/common/image/favicon.ico');
# 					$('title').text('Melon');
# 				}else if('IS20' == pocId || 'IT10' == pocId){
# 					$('link#favicon').attr('type','');
# 					$('link#favicon').attr('rel','apple-touch-icon-precomposed');
# 					$('link#favicon').attr('href','http://cdnimg.melon.co.kr/resource/mobile40/cds/common/image/mobile_apple_120x120.png');
# 					$('link#favicon').after('<link rel="apple-touch-icon-precomposed" sizes="180x180" href="http://cdnimg.melon.co.kr/resource/mobile40/cds/common/image/mobile_apple_180x180.png" />');
# 					$('title').text('Melon');
# 				}
#
#
# 				// 모바일(t.com)에서 넘어온 경우 - 모바일(t.com) 서비스 종료로 삭제
# /*
# 				var fromMobileWeb = getCookie("D");
#
# 				if(fromMobileWeb != null && fromMobileWeb.indexOf('T') > -1){
# 					$("#btnMobileWeb").css("display", "block");
# 				}
# */
# 				// 엣지 브라우저이고 해당 팝업이 뜬 적이 없는 경우 체크하여 팝업을 띄운다.
# 				var isEdge = (navigator.userAgent.indexOf("Edge") > 0);
# 				var edgeCheckYN = getCookie("EDGE_CHECK") != 'Y';
#
# 				if(isEdge && edgeCheckYN){
# 					window.open('http://www.melon.com/error_page/error_edgeTypeA.html','edgeCheck','scrollbars=no, resizable=no, location=no, width=560, height=498');
# 				}
#
# 				// 타블렛이고 해당 팝업이 뜬 적이 없는 경우 체크하여 팝업을 띄운다.
# 				var tabletCheckYN = getCookie("TABLET_CHECK") != 'Y';
#
# 				if(melon.isTablet() && tabletCheckYN){
# 					window.open('http://www.melon.com/error_page/error_tabletTypeA.html','tabletPopTypeA','scrollbars=no, resizable=no, location=no, width=560, height=483');
# 				}
#
# 				// 해당 쿠키가 존재하면 쿠키 삭제
# 				if(getCookie("CHECK_POP") != ''){
# 					// 체크 후 해당 쿠키는 제거
# 					var expireDate = new Date();
# 					expireDate.setDate(expireDate.getDate()-1);
# 					document.cookie = "CHECK_POP=;path=/;expires="+expireDate.toGMTString()+";domain=.melon.com";
# 				}
#
# 				if(isMelonLogin()){
# 					var djYn = getMemberDjYn();
# 					if(djYn == "" || typeof djYn == "undefined"){
# 						try {
# 							$.ajax({
# 								url: "http://www.melon.com/gnb/check_melondj.json",
# 								type : 'GET',
# 								dataType: 'jsonp',
# 								jsonp: 'jscallback',
# 							}).done(function(json) {}).fail(function() {});
# 						} catch(e){}
# 					}
# 				}
#
# 				// 홈탭의 경우 쇼핑/티켓을 새창띄우기로 변경한다.
# 				var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
# 				var fromHomeTab = !(fromMPS == null || fromMPS.indexOf("MELONPLAYER") < 0);
#
# 				if(fromHomeTab){
# 					$("li.d_melon_shopping a").removeClass("mlog");
# 					$("li.d_melon_shopping a").addClass("mlog_without_page_change");
# 					$("li.d_melon_shopping a").attr("target", "_blank");
#
# 					$("li.d_melon_ticket a").removeClass("mlog");
# 					$("li.d_melon_ticket a").addClass("mlog_without_page_change");
# 					$("li.d_melon_ticket a").attr("target", "_blank");
# 				}
#
# 				//SHA-2 popup
# 				function uaChecker() {
# 					var r = true;
# 					var uav = navigator.userAgent.replace(/ /g,'');
# 					var exUA = ['OSX10_1_','OSX10_2_','OSX10_3_','OSX10_4_','OSX10.1.','OSX10.2.','OSX10.3.','OSX10.4.',
# 					            'Windows95','Windows98','WindowsNT4.0','WindowsNT5.0','MSIE6'];
# 					$.each(exUA, function(i,v) {
# 						if ( uav.indexOf(v) > -1 ) {
# 							r = false;
# 						}
# 					});
# 					if ( uav.indexOf("WindowsNT5.1") > -1 && uav.indexOf("SV1") > -1 ) {
# 						r = false;
# 					}
# 					var chp = uav.indexOf("Chrome");
# 					if(chp > -1){ if ( parseInt(uav.substr(chp + 7, 3)) < 26 ) { r = false; } }
# 					if(chp == -1 && uav.indexOf("Safari") > -1) { if ( parseInt(uav.substr(uav.indexOf("Version") + 8, 3)) < 3 ) { r = false; } }
# 					if(uav.indexOf("Firefox") > -1) { if ( parseFloat(uav.substr(uav.indexOf("Firefox") + 8, 3)) < 2 ) { r = false; } }
# 					if(uav.indexOf("OPR/") > -1 || uav.indexOf("Opera/") > -1) {
# 						var fv = 0;
# 						if ( uav.indexOf("OPR/") > -1 ) { fv = parseFloat(uav.substr(uav.indexOf("OPR/") + 4, 3)); }
# 						else if ( uav.indexOf("Opera/") > -1 ) { fv = parseFloat(uav.substr(uav.indexOf("Opera/") + 6, 3)); }
# 						if ( fv < 7 ) { r = false; }
# 					}
# 					return r;
# 				}
#
# 				 //웹 브라우저 보안 암호화 161121
# 		        $('.d_check_on').on('click','label',function () {
# 		            if ($(this).siblings('input').prop('checked')) {
# 		                $(this).parents('.d_check_on').removeClass('on');
# 		            } else {
# 		                $(this).parents('.d_check_on').addClass('on');
# 		            };
# 		        });
# 		        $(document).on('limitpopup', function( e, cookieId ) {
# 					if ( !uaChecker() ) {
# 						$('#'+cookieId).modal();
# 					}
# 				});
# 		        setTimeout(function() {
# 		            $("#popNotice").timeLimitSet({ cookieId:'popNotice',selectors:{closebtn:'#todayChk', checkbox:''} });
# 		        },1);
# 		        MELON.PBPGN.TimeLimitPopup.init({ cookieId:"popNotice", serverTime: new Date(), limitType:"day" });
# 		        $("#popNotice .d_close").click(function() {  $("#popNotice").modal('hide'); });
# 			});
#
# 			function goMelonTPage(){
# 				// 쿠키 삭제 후 t.com으로 페이지 이동
# 				var expireDate = new Date();
# 				expireDate.setDate(expireDate.getDate()-1);
# 				document.cookie = "D=;path=/;expires="+expireDate.toGMTString()+";domain=.melon.com";
#
# 				location.href= 'http://t.melon.com';
# 			}
#
# 			function openEmailCollectionReject(){
# 				window.open('http://www.melon.com/emailCollectionReject.html','emailCollect', 'scrollbars=no, resizable=no, location=no, width=384, height=331');
# 			}
#
# 			//다음 검색 랜딩 추가
# 			if(location.href.indexOf('ref=W10600') > -1){
# 				$.ajax({
# 					url: '/gnb/daumsearch_list.htm',
# 				}).done(function(html){
# 					$('#footer').before(html);
# 				});
# 			}
#
#
# 		</script>
# <!--//140602 추가 lyr-->
# </div>
# <!-- //footer -->
# </div>
# </body>
# </html>

# %%
tmp_tag = soup.find('tbody')

# %%
tmp_tag
# Out:
# <tbody>
# <tr class="lst50" data-song-no="30859584" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="사랑을 했다 (LOVE SCENARIO) 곡 선택" type="checkbox" value="30859584"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10132945');" title="Return">
# <img alt="Return - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/32/945/10132945_500.jpg/melon/resize/120/quality/80/optimize" width="60">
# <span class="bg_album_frame"></span>
# </img></a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30859584');" title="사랑을 했다 (LOVE SCENARIO) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30859584);" title="사랑을 했다 (LOVE SCENARIO) 재생">사랑을 했다 (LOVE SCENARIO)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10132945');" title="Return - 페이지 이동">Return</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30859584" title="사랑을 했다 (LOVE SCENARIO) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30859584);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30859584');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30859584', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30859584','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30859584')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30816860" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="뿜뿜 곡 선택" type="checkbox" value="30816860"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">2</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT!">
# <img alt="GREAT! - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/24/822/10124822_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30816860');" title="뿜뿜 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30816860);" title="뿜뿜 재생">뿜뿜</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT! - 페이지 이동">GREAT!</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30816860" title="뿜뿜 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30816860);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30816860');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30816860', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30816860','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30816860')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30755375" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="그날처럼 곡 선택" type="checkbox" value="30755375"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">3</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼">
# <img alt="그날처럼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/15/186/10115186_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30755375');" title="그날처럼 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30755375);" title="그날처럼 재생">그날처럼</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼 - 페이지 이동">그날처럼</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30755375" title="그날처럼 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30755375);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30755375');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30755375', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30755375','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30755375')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30884950" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="그때 헤어지면 돼 곡 선택" type="checkbox" value="30884950"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">4</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼">
# <img alt="그때 헤어지면 돼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/37/574/10137574_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30884950');" title="그때 헤어지면 돼 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30884950);" title="그때 헤어지면 돼 재생">그때 헤어지면 돼</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼 - 페이지 이동">그때 헤어지면 돼</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30884950" title="그때 헤어지면 돼 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30884950);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30884950');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30884950', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30884950','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30884950')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30864993" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Bad Boy 곡 선택" type="checkbox" value="30864993"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">5</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage">
# <img alt="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/34/032/10134032_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30864993');" title="Bad Boy 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30864993);" title="Bad Boy 재생">Bad Boy</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동">The Perfect Red Velvet - The 2nd Album Repackage</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30864993" title="Bad Boy 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30864993);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30864993');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30864993', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30864993','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30864993')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30567963" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Havana (Feat. Young Thug) 곡 선택" type="checkbox" value="30567963"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">6</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila">
# <img alt="Camila - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/85/877/10085877_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30567963');" title="Havana (Feat. Young Thug) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30567963);" title="Havana (Feat. Young Thug) 재생">Havana (Feat. Young Thug)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila - 페이지 이동">Camila</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30567963" title="Havana (Feat. Young Thug) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30567963);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30567963');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30567963', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30567963','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30567963')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30844118" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Roller Coaster 곡 선택" type="checkbox" value="30844118"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">7</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10129940');" title="Offset">
# <img alt="Offset - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/29/940/10129940_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30844118');" title="Roller Coaster 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30844118);" title="Roller Coaster 재생">Roller Coaster</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('968265');" title="청하 - 페이지 이동">청하</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('968265');" title="청하 - 페이지 이동">청하</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10129940');" title="Offset - 페이지 이동">Offset</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30844118" title="Roller Coaster 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30844118);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30844118');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30844118', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30844118','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30844118')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30514366" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="선물 곡 선택" type="checkbox" value="30514366"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">8</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10078176');" title="Moonlight">
# <img alt="Moonlight - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/78/176/10078176_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30514366');" title="선물 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30514366);" title="선물 재생">선물</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10078176');" title="Moonlight - 페이지 이동">Moonlight</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30514366" title="선물 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30514366);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30514366');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30514366', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30514366','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30514366')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="8111603" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="HandClap 곡 선택" type="checkbox" value="8111603"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">9</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2675179');" title="Fitz and The Tantrums (Deluxe)">
# <img alt="Fitz and The Tantrums (Deluxe) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/026/75/179/2675179_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('8111603');" title="HandClap 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',8111603);" title="HandClap 재생">HandClap</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('750471');" title="Fitz &amp; The Tantrums - 페이지 이동">Fitz &amp; The Tantrums</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('750471');" title="Fitz &amp; The Tantrums - 페이지 이동">Fitz &amp; The Tantrums</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('2675179');" title="Fitz and The Tantrums (Deluxe) - 페이지 이동">Fitz and The Tantrums (Deluxe)</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="8111603" title="HandClap 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',8111603);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('8111603');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '8111603', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '8111603','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','8111603')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30086173" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="비행운 곡 선택" type="checkbox" value="30086173"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">10</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10013929');" title="LIFE IS BEAUTY FULL">
# <img alt="LIFE IS BEAUTY FULL - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/13/929/10013929_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30086173');" title="비행운 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30086173);" title="비행운 재생">비행운</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('927668');" title="문문 (MoonMoon) - 페이지 이동">문문 (MoonMoon)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('927668');" title="문문 (MoonMoon) - 페이지 이동">문문 (MoonMoon)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10013929');" title="LIFE IS BEAUTY FULL - 페이지 이동">LIFE IS BEAUTY FULL</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30086173" title="비행운 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30086173);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30086173');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30086173', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30086173','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1100000000000000','30086173')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30838076" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="주인공 곡 선택" type="checkbox" value="30838076"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">11</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10128855');" title="주인공">
# <img alt="주인공 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/28/855/10128855_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30838076');" title="주인공 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30838076);" title="주인공 재생">주인공</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('22938');" title="선미 - 페이지 이동">선미</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('22938');" title="선미 - 페이지 이동">선미</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10128855');" title="주인공 - 페이지 이동">주인공</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30838076" title="주인공 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30838076);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30838076');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30838076', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30838076','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30838076')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30877002" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="눈사람 곡 선택" type="checkbox" value="30877002"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">12</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10136251');" title="그리고 봄">
# <img alt="그리고 봄 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/36/251/10136251_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30877002');" title="눈사람 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30877002);" title="눈사람 재생">눈사람</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('792091');" title="정승환 - 페이지 이동">정승환</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('792091');" title="정승환 - 페이지 이동">정승환</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10136251');" title="그리고 봄 - 페이지 이동">그리고 봄</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30877002" title="눈사람 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30877002);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30877002');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30877002', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30877002','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30877002')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30806580" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="instagram 곡 선택" type="checkbox" value="30806580"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">13</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10122929');" title="instagram">
# <img alt="instagram - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/22/929/10122929_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30806580');" title="instagram 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30806580);" title="instagram 재생">instagram</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('880630');" title="DEAN - 페이지 이동">DEAN</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('880630');" title="DEAN - 페이지 이동">DEAN</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10122929');" title="instagram - 페이지 이동">instagram</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30806580" title="instagram 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30806580);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30806580');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30806580', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30806580','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30806580')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30829858" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="#첫사랑 곡 선택" type="checkbox" value="30829858"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">14</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10127486');" title="#첫사랑">
# <img alt="#첫사랑 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/27/486/10127486_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30829858');" title="#첫사랑 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30829858);" title="#첫사랑 재생">#첫사랑</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10127486');" title="#첫사랑 - 페이지 이동">#첫사랑</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30829858" title="#첫사랑 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30829858);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30829858');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30829858', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30829858','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30829858')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30659630" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="밤이 되니까 곡 선택" type="checkbox" value="30659630"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">15</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10100577');" title="밤이 되니까">
# <img alt="밤이 되니까 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/00/577/10100577_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30659630');" title="밤이 되니까 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30659630);" title="밤이 되니까 재생">밤이 되니까</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('749640');" title="펀치 (Punch) - 페이지 이동">펀치 (Punch)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('749640');" title="펀치 (Punch) - 페이지 이동">펀치 (Punch)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10100577');" title="밤이 되니까 - 페이지 이동">밤이 되니까</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30659630" title="밤이 되니까 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30659630);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30659630');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30659630', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30659630','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30659630')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="30637776" id="lst50">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="이 별 곡 선택" type="checkbox" value="30637776"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">16</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10097064');" title="Star">
# <img alt="Star - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/97/064/10097064_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# ...
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Best Of Me 곡 선택" type="checkbox" value="30637983"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">96</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="1단계 하락">
# <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
# <span class="down">1</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10097112');" title="LOVE YOURSELF 承 `Her`">
# <img alt="LOVE YOURSELF 承 `Her` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/97/112/10097112_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30637983');" title="Best Of Me 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30637983);" title="Best Of Me 재생">Best Of Me</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10097112');" title="LOVE YOURSELF 承 `Her` - 페이지 이동">LOVE YOURSELF 承 `Her`</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30637983" title="Best Of Me 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30637983);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30637983');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30637983', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30637983','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1100000000000000','30637983')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="30878837" id="lst100" style="display:none;">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Thinkin` about you 곡 선택" type="checkbox" value="30878837"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">97</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="1단계 상승">
# <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
# <span class="up">1</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`">
# <img alt="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/36/531/10136531_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30878837');" title="Thinkin` about you 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30878837);" title="Thinkin` about you 재생">Thinkin` about you</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동">SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30878837" title="Thinkin` about you 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30878837);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30878837');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30878837', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30878837','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30878837')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="91264" id="lst100" style="display:none;">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="행복 곡 선택" type="checkbox" value="91264"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">98</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 진입">
# <span class="bullet_icons rank_new"><span class="none">순위 진입</span></span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('5284');" title="Wolf and Sheep">
# <img alt="Wolf and Sheep - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/000/05/284/5284_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('91264');" title="행복 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',91264);" title="행복 재생">행복</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('100008');" title="H.O.T. - 페이지 이동">H.O.T.</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('100008');" title="H.O.T. - 페이지 이동">H.O.T.</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('5284');" title="Wolf and Sheep - 페이지 이동">Wolf and Sheep</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="91264" title="행복 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',91264);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('91264');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '91264', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '91264','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1101010000000000','91264')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="30550293" id="lst100" style="display:none;">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="사랑하지 않은 것처럼 곡 선택" type="checkbox" value="30550293"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">99</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="1단계 상승">
# <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
# <span class="up">1</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10083276');" title="`Be One` - Buzz The 1st Mini Album">
# <img alt="`Be One` - Buzz The 1st Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/83/276/10083276_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30550293');" title="사랑하지 않은 것처럼 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30550293);" title="사랑하지 않은 것처럼 재생">사랑하지 않은 것처럼</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10083276');" title="`Be One` - Buzz The 1st Mini Album - 페이지 이동">`Be One` - Buzz The 1st Mini Album</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30550293" title="사랑하지 않은 것처럼 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30550293);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30550293');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30550293', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30550293','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30550293')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# <tr class="lst100" data-song-no="30874386" id="lst100" style="display:none;">
# <td><div class="wrap t_right"><input class="input_check " name="input_check" title="마지막으로 안아도 될까 곡 선택" type="checkbox" value="30874386"/></div></td>
# <td><div class="wrap t_center"><span class="rank ">100</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="4단계 하락">
# <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
# <span class="down">4</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10135777');" title="마지막으로 안아도 될까">
# <img alt="마지막으로 안아도 될까 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/35/777/10135777_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30874386');" title="마지막으로 안아도 될까 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',30874386);" title="마지막으로 안아도 될까 재생">마지막으로 안아도 될까</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('10135777');" title="마지막으로 안아도 될까 - 페이지 이동">마지막으로 안아도 될까</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="30874386" title="마지막으로 안아도 될까 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play " onclick="melon.play.playSong('19041201',30874386);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap " onclick="melon.play.addPlayList('30874386');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30874386', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30874386','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30874386')" title="링/벨" type="button"><span class="none">링/벨</span></button>
# </div></td>
# </tr>
# </tbody>

# %%
tmp_tag.find_all('span', 'rank')
# Out:
# [<span class="rank ">1</span>,
#  <span class="rank ">2</span>,
#  <span class="rank ">3</span>,
#  <span class="rank ">4</span>,
#  <span class="rank ">5</span>,
#  <span class="rank ">6</span>,
#  <span class="rank ">7</span>,
#  <span class="rank ">8</span>,
#  <span class="rank ">9</span>,
#  <span class="rank ">10</span>,
#  <span class="rank ">11</span>,
#  <span class="rank ">12</span>,
#  <span class="rank ">13</span>,
#  <span class="rank ">14</span>,
#  <span class="rank ">15</span>,
#  <span class="rank ">16</span>,
#  <span class="rank ">17</span>,
#  <span class="rank ">18</span>,
#  <span class="rank ">19</span>,
#  <span class="rank ">20</span>,
#  <span class="rank ">21</span>,
#  <span class="rank ">22</span>,
#  <span class="rank ">23</span>,
#  <span class="rank ">24</span>,
#  <span class="rank ">25</span>,
#  <span class="rank ">26</span>,
#  <span class="rank ">27</span>,
#  <span class="rank ">28</span>,
#  <span class="rank ">29</span>,
#  <span class="rank ">30</span>,
#  <span class="rank ">31</span>,
#  <span class="rank ">32</span>,
#  <span class="rank ">33</span>,
#  <span class="rank ">34</span>,
#  <span class="rank ">35</span>,
#  <span class="rank ">36</span>,
#  <span class="rank ">37</span>,
#  <span class="rank ">38</span>,
#  <span class="rank ">39</span>,
#  <span class="rank ">40</span>,
#  <span class="rank ">41</span>,
#  <span class="rank ">42</span>,
#  <span class="rank ">43</span>,
#  <span class="rank ">44</span>,
#  <span class="rank ">45</span>,
#  <span class="rank ">46</span>,
#  <span class="rank ">47</span>,
#  <span class="rank ">48</span>,
#  <span class="rank ">49</span>,
#  <span class="rank ">50</span>,
#  <span class="rank ">51</span>,
#  <span class="rank ">52</span>,
#  <span class="rank ">53</span>,
#  <span class="rank ">54</span>,
#  <span class="rank ">55</span>,
#  <span class="rank ">56</span>,
#  <span class="rank ">57</span>,
#  <span class="rank ">58</span>,
#  <span class="rank ">59</span>,
#  <span class="rank ">60</span>,
#  <span class="rank ">61</span>,
#  <span class="rank ">62</span>,
#  <span class="rank ">63</span>,
#  <span class="rank ">64</span>,
#  <span class="rank ">65</span>,
#  <span class="rank ">66</span>,
#  <span class="rank ">67</span>,
#  <span class="rank ">68</span>,
#  <span class="rank ">69</span>,
#  <span class="rank ">70</span>,
#  <span class="rank ">71</span>,
#  <span class="rank ">72</span>,
#  <span class="rank ">73</span>,
#  <span class="rank ">74</span>,
#  <span class="rank ">75</span>,
#  <span class="rank ">76</span>,
#  <span class="rank ">77</span>,
#  <span class="rank ">78</span>,
#  <span class="rank ">79</span>,
#  <span class="rank ">80</span>,
#  <span class="rank ">81</span>,
#  <span class="rank ">82</span>,
#  <span class="rank ">83</span>,
#  <span class="rank ">84</span>,
#  <span class="rank ">85</span>,
#  <span class="rank ">86</span>,
#  <span class="rank ">87</span>,
#  <span class="rank ">88</span>,
#  <span class="rank ">89</span>,
#  <span class="rank ">90</span>,
#  <span class="rank ">91</span>,
#  <span class="rank ">92</span>,
#  <span class="rank ">93</span>,
#  <span class="rank ">94</span>,
#  <span class="rank ">95</span>,
#  <span class="rank ">96</span>,
#  <span class="rank ">97</span>,
#  <span class="rank ">98</span>,
#  <span class="rank ">99</span>,
#  <span class="rank ">100</span>]

# %%
a_tag = tmp_tag.find_all("a")
a_tag
# Out:
# [<a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10132945');" title="Return">
#  <img alt="Return - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/32/945/10132945_500.jpg/melon/resize/120/quality/80/optimize" width="60">
#  <span class="bg_album_frame"></span>
#  </img></a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30859584');" title="사랑을 했다 (LOVE SCENARIO) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30859584);" title="사랑을 했다 (LOVE SCENARIO) 재생">사랑을 했다 (LOVE SCENARIO)</a>,
#  <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a>,
#  <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10132945');" title="Return - 페이지 이동">Return</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT!">
#  <img alt="GREAT! - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/24/822/10124822_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30816860');" title="뿜뿜 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30816860);" title="뿜뿜 재생">뿜뿜</a>,
#  <a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a>,
#  <a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT! - 페이지 이동">GREAT!</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼">
#  <img alt="그날처럼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/15/186/10115186_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30755375');" title="그날처럼 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30755375);" title="그날처럼 재생">그날처럼</a>,
#  <a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a>,
#  <a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼 - 페이지 이동">그날처럼</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼">
#  <img alt="그때 헤어지면 돼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/37/574/10137574_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30884950');" title="그때 헤어지면 돼 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30884950);" title="그때 헤어지면 돼 재생">그때 헤어지면 돼</a>,
#  <a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a>,
#  <a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼 - 페이지 이동">그때 헤어지면 돼</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage">
#  <img alt="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/34/032/10134032_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30864993');" title="Bad Boy 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30864993);" title="Bad Boy 재생">Bad Boy</a>,
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a>,
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동">The Perfect Red Velvet - The 2nd Album Repackage</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila">
#  <img alt="Camila - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/85/877/10085877_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30567963');" title="Havana (Feat. Young Thug) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30567963);" title="Havana (Feat. Young Thug) 재생">Havana (Feat. Young Thug)</a>,
#  <a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a>,
#  <a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila - 페이지 이동">Camila</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10129940');" title="Offset">
#  <img alt="Offset - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/29/940/10129940_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30844118');" title="Roller Coaster 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30844118);" title="Roller Coaster 재생">Roller Coaster</a>,
#  <a href="javascript:melon.link.goArtistDetail('968265');" title="청하 - 페이지 이동">청하</a>,
#  <a href="javascript:melon.link.goArtistDetail('968265');" title="청하 - 페이지 이동">청하</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10129940');" title="Offset - 페이지 이동">Offset</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10078176');" title="Moonlight">
#  <img alt="Moonlight - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/78/176/10078176_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30514366');" title="선물 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30514366);" title="선물 재생">선물</a>,
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a>,
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10078176');" title="Moonlight - 페이지 이동">Moonlight</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2675179');" title="Fitz and The Tantrums (Deluxe)">
#  <img alt="Fitz and The Tantrums (Deluxe) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/026/75/179/2675179_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('8111603');" title="HandClap 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',8111603);" title="HandClap 재생">HandClap</a>,
#  <a href="javascript:melon.link.goArtistDetail('750471');" title="Fitz &amp; The Tantrums - 페이지 이동">Fitz &amp; The Tantrums</a>,
#  <a href="javascript:melon.link.goArtistDetail('750471');" title="Fitz &amp; The Tantrums - 페이지 이동">Fitz &amp; The Tantrums</a>,
#  <a href="javascript:melon.link.goAlbumDetail('2675179');" title="Fitz and The Tantrums (Deluxe) - 페이지 이동">Fitz and The Tantrums (Deluxe)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10013929');" title="LIFE IS BEAUTY FULL">
#  <img alt="LIFE IS BEAUTY FULL - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/13/929/10013929_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30086173');" title="비행운 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30086173);" title="비행운 재생">비행운</a>,
#  <a href="javascript:melon.link.goArtistDetail('927668');" title="문문 (MoonMoon) - 페이지 이동">문문 (MoonMoon)</a>,
#  <a href="javascript:melon.link.goArtistDetail('927668');" title="문문 (MoonMoon) - 페이지 이동">문문 (MoonMoon)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10013929');" title="LIFE IS BEAUTY FULL - 페이지 이동">LIFE IS BEAUTY FULL</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10128855');" title="주인공">
#  <img alt="주인공 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/28/855/10128855_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30838076');" title="주인공 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30838076);" title="주인공 재생">주인공</a>,
#  <a href="javascript:melon.link.goArtistDetail('22938');" title="선미 - 페이지 이동">선미</a>,
#  <a href="javascript:melon.link.goArtistDetail('22938');" title="선미 - 페이지 이동">선미</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10128855');" title="주인공 - 페이지 이동">주인공</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10136251');" title="그리고 봄">
#  <img alt="그리고 봄 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/36/251/10136251_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30877002');" title="눈사람 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30877002);" title="눈사람 재생">눈사람</a>,
#  <a href="javascript:melon.link.goArtistDetail('792091');" title="정승환 - 페이지 이동">정승환</a>,
#  <a href="javascript:melon.link.goArtistDetail('792091');" title="정승환 - 페이지 이동">정승환</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10136251');" title="그리고 봄 - 페이지 이동">그리고 봄</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10122929');" title="instagram">
#  <img alt="instagram - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/22/929/10122929_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30806580');" title="instagram 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30806580);" title="instagram 재생">instagram</a>,
#  <a href="javascript:melon.link.goArtistDetail('880630');" title="DEAN - 페이지 이동">DEAN</a>,
#  <a href="javascript:melon.link.goArtistDetail('880630');" title="DEAN - 페이지 이동">DEAN</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10122929');" title="instagram - 페이지 이동">instagram</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10127486');" title="#첫사랑">
#  <img alt="#첫사랑 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/27/486/10127486_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30829858');" title="#첫사랑 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30829858);" title="#첫사랑 재생">#첫사랑</a>,
#  <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a>,
#  <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10127486');" title="#첫사랑 - 페이지 이동">#첫사랑</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10100577');" title="밤이 되니까">
#  <img alt="밤이 되니까 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/00/577/10100577_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30659630');" title="밤이 되니까 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30659630);" title="밤이 되니까 재생">밤이 되니까</a>,
#  <a href="javascript:melon.link.goArtistDetail('749640');" title="펀치 (Punch) - 페이지 이동">펀치 (Punch)</a>,
#  <a href="javascript:melon.link.goArtistDetail('749640');" title="펀치 (Punch) - 페이지 이동">펀치 (Punch)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10100577');" title="밤이 되니까 - 페이지 이동">밤이 되니까</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10097064');" title="Star">
#  <img alt="Star - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/97/064/10097064_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30637776');" title="이 별 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30637776);" title="이 별 재생">이 별</a>,
#  <a href="javascript:melon.link.goArtistDetail('500421');" title="길구봉구 - 페이지 이동">길구봉구</a>,
#  <a href="javascript:melon.link.goArtistDetail('500421');" title="길구봉구 - 페이지 이동">길구봉구</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10097064');" title="Star - 페이지 이동">Star</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10118955');" title="Merry &amp; Happy">
#  <img alt="Merry &amp; Happy - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/18/955/10118955_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30781481');" title="Heart Shaker 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30781481);" title="Heart Shaker 재생">Heart Shaker</a>,
#  <a href="javascript:melon.link.goArtistDetail('905701');" title="TWICE (트와이스) - 페이지 이동">TWICE (트와이스)</a>,
#  <a href="javascript:melon.link.goArtistDetail('905701');" title="TWICE (트와이스) - 페이지 이동">TWICE (트와이스)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10118955');" title="Merry &amp; Happy - 페이지 이동">Merry &amp; Happy</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10073513');" title="LISTEN 010 좋니">
#  <img alt="LISTEN 010 좋니 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/73/513/10073513_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30486509');" title="좋니 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30486509);" title="좋니 재생">좋니</a>,
#  <a href="javascript:melon.link.goArtistDetail('437');" title="윤종신 - 페이지 이동">윤종신</a>,
#  <a href="javascript:melon.link.goArtistDetail('437');" title="윤종신 - 페이지 이동">윤종신</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10073513');" title="LISTEN 010 좋니 - 페이지 이동">LISTEN 010 좋니</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10110396');" title="돈꽃 OST Part.1">
#  <img alt="돈꽃 OST Part.1 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/10/396/10110396_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30721801');" title="My Way 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30721801);" title="My Way 재생">My Way</a>,
#  <a href="javascript:melon.link.goArtistDetail('214784');" title="이수 (엠씨 더 맥스) - 페이지 이동">이수 (엠씨 더 맥스)</a>,
#  <a href="javascript:melon.link.goArtistDetail('214784');" title="이수 (엠씨 더 맥스) - 페이지 이동">이수 (엠씨 더 맥스)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10110396');" title="돈꽃 OST Part.1 - 페이지 이동">돈꽃 OST Part.1</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10083290');" title="0M">
#  <img alt="0M - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/83/290/10083290_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30550388');" title="all of my life 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30550388);" title="all of my life 재생">all of my life</a>,
#  <a href="javascript:melon.link.goArtistDetail('41499');" title="박원 - 페이지 이동">박원</a>,
#  <a href="javascript:melon.link.goArtistDetail('41499');" title="박원 - 페이지 이동">박원</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10083290');" title="0M - 페이지 이동">0M</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10131396');" title="Faces of Love">
#  <img alt="Faces of Love - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/31/396/10131396_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30851703');" title="다른사람을 사랑하고 있어 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30851703);" title="다른사람을 사랑하고 있어 재생">다른사람을 사랑하고 있어</a>,
#  <a href="javascript:melon.link.goArtistDetail('514741');" title="수지 (SUZY) - 페이지 이동">수지 (SUZY)</a>,
#  <a href="javascript:melon.link.goArtistDetail('514741');" title="수지 (SUZY) - 페이지 이동">수지 (SUZY)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10131396');" title="Faces of Love - 페이지 이동">Faces of Love</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10102177');" title="가을 안부">
#  <img alt="가을 안부 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/02/177/10102177_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30669593');" title="가을 안부 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30669593);" title="가을 안부 재생">가을 안부</a>,
#  <a href="javascript:melon.link.goArtistDetail('175155');" title="먼데이 키즈 - 페이지 이동">먼데이 키즈</a>,
#  <a href="javascript:melon.link.goArtistDetail('175155');" title="먼데이 키즈 - 페이지 이동">먼데이 키즈</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10102177');" title="가을 안부 - 페이지 이동">가을 안부</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10097112');" title="LOVE YOURSELF 承 `Her`">
#  <img alt="LOVE YOURSELF 承 `Her` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/97/112/10097112_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30637982');" title="DNA 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30637982);" title="DNA 재생">DNA</a>,
#  <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a>,
#  <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10097112');" title="LOVE YOURSELF 承 `Her` - 페이지 이동">LOVE YOURSELF 承 `Her`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10028835');" title="÷ (Deluxe)">
#  <img alt="÷ (Deluxe) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/28/835/10028835_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30188113');" title="Shape of You 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30188113);" title="Shape of You 재생">Shape of You</a>,
#  <a href="javascript:melon.link.goArtistDetail('549800');" title="Ed Sheeran - 페이지 이동">Ed Sheeran</a>,
#  <a href="javascript:melon.link.goArtistDetail('549800');" title="Ed Sheeran - 페이지 이동">Ed Sheeran</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10028835');" title="÷ (Deluxe) - 페이지 이동">÷ (Deluxe)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10105438');" title="REMEMBER ME">
#  <img alt="REMEMBER ME - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/05/438/10105438_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30690674');" title="눈 떠보니 이별이더라 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30690674);" title="눈 떠보니 이별이더라 재생">눈 떠보니 이별이더라</a>,
#  <a href="javascript:melon.link.goArtistDetail('100176');" title="포맨 - 페이지 이동">포맨</a>,
#  <a href="javascript:melon.link.goArtistDetail('100176');" title="포맨 - 페이지 이동">포맨</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10105438');" title="REMEMBER ME - 페이지 이동">REMEMBER ME</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10107114');" title="twicetagram">
#  <img alt="twicetagram - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/07/114/10107114_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30700708');" title="LIKEY 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30700708);" title="LIKEY 재생">LIKEY</a>,
#  <a href="javascript:melon.link.goArtistDetail('905701');" title="TWICE (트와이스) - 페이지 이동">TWICE (트와이스)</a>,
#  <a href="javascript:melon.link.goArtistDetail('905701');" title="TWICE (트와이스) - 페이지 이동">TWICE (트와이스)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10107114');" title="twicetagram - 페이지 이동">twicetagram</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10115433');" title="기억의 빈자리">
#  <img alt="기억의 빈자리 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/15/433/10115433_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30757693');" title="기억의 빈자리 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30757693);" title="기억의 빈자리 재생">기억의 빈자리</a>,
#  <a href="javascript:melon.link.goArtistDetail('3959');" title="나얼 - 페이지 이동">나얼</a>,
#  <a href="javascript:melon.link.goArtistDetail('3959');" title="나얼 - 페이지 이동">나얼</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10115433');" title="기억의 빈자리 - 페이지 이동">기억의 빈자리</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10102658');" title="Brother Act.">
#  <img alt="Brother Act. - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/02/658/10102658_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30672529');" title="그리워하다 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30672529);" title="그리워하다 재생">그리워하다</a>,
#  <a href="javascript:melon.link.goArtistDetail('647971');" title="비투비 - 페이지 이동">비투비</a>,
#  <a href="javascript:melon.link.goArtistDetail('647971');" title="비투비 - 페이지 이동">비투비</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10102658');" title="Brother Act. - 페이지 이동">Brother Act.</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10128163');" title="답장">
#  <img alt="답장 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/28/163/10128163_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30833270');" title="답장 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30833270);" title="답장 재생">답장</a>,
#  <a href="javascript:melon.link.goArtistDetail('925');" title="김동률 - 페이지 이동">김동률</a>,
#  <a href="javascript:melon.link.goArtistDetail('925');" title="김동률 - 페이지 이동">김동률</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10128163');" title="답장 - 페이지 이동">답장</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10093389');" title="시차 (We Are)">
#  <img alt="시차 (We Are) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/93/389/10093389_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30613202');" title="시차 (We Are) (Feat. 로꼬 &amp; GRAY) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30613202);" title="시차 (We Are) (Feat. 로꼬 &amp; GRAY) 재생">시차 (We Are) (Feat. 로꼬 &amp; GRAY)</a>,
#  <a href="javascript:melon.link.goArtistDetail('1866689');" title="우원재 - 페이지 이동">우원재</a>,
#  <a href="javascript:melon.link.goArtistDetail('1866689');" title="우원재 - 페이지 이동">우원재</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10093389');" title="시차 (We Are) - 페이지 이동">시차 (We Are)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10112486');" title="Perfect Velvet - The 2nd Album">
#  <img alt="Perfect Velvet - The 2nd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/12/486/10112486_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30736437');" title="피카부 (Peek-A-Boo) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30736437);" title="피카부 (Peek-A-Boo) 재생">피카부 (Peek-A-Boo)</a>,
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a>,
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10112486');" title="Perfect Velvet - The 2nd Album - 페이지 이동">Perfect Velvet - The 2nd Album</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10111490');" title="2017 월간 윤종신 11월호">
#  <img alt="2017 월간 윤종신 11월호 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/11/490/10111490_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30729198');" title="좋아 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30729198);" title="좋아 재생">좋아</a>,
#  <a href="javascript:melon.link.goArtistDetail('906283');" title="민서 - 페이지 이동">민서</a>,
#  <a href="javascript:melon.link.goArtistDetail('437');" title="윤종신 - 페이지 이동">윤종신</a>,
#  <a href="javascript:melon.link.goArtistDetail('906283');" title="민서 - 페이지 이동">민서</a>,
#  <a href="javascript:melon.link.goArtistDetail('437');" title="윤종신 - 페이지 이동">윤종신</a>,
#  <a class="ellipsis" href="javascript:melon.link.goArtistDetail('906283');" title="민서 페이지 이동">민서</a>,
#  <a class="ellipsis" href="javascript:melon.link.goArtistDetail('437');" title="윤종신 페이지 이동">윤종신</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10111490');" title="2017 월간 윤종신 11월호 - 페이지 이동">2017 월간 윤종신 11월호</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10047890');" title="밤편지">
#  <img alt="밤편지 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/47/890/10047890_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30314784');" title="밤편지 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30314784);" title="밤편지 재생">밤편지</a>,
#  <a href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a>,
#  <a href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10047890');" title="밤편지 - 페이지 이동">밤편지</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10100191');" title="Red Diary Page.1">
#  <img alt="Red Diary Page.1 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/00/191/10100191_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30657307');" title="썸 탈꺼야 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30657307);" title="썸 탈꺼야 재생">썸 탈꺼야</a>,
#  <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a>,
#  <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10100191');" title="Red Diary Page.1 - 페이지 이동">Red Diary Page.1</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10131018');" title="투유 프로젝트 - 슈가맨2 Part.2">
#  <img alt="투유 프로젝트 - 슈가맨2 Part.2 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/31/018/10131018_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30849733');" title="You 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30849733);" title="You 재생">You</a>,
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a>,
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10131018');" title="투유 프로젝트 - 슈가맨2 Part.2 - 페이지 이동">투유 프로젝트 - 슈가맨2 Part.2</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2689280');" title="Illuminate (New Deluxe Ver.)">
#  <img alt="Illuminate (New Deluxe Ver.) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/026/89/280/2689280_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30380953');" title="There`s Nothing Holdin` Me Back 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30380953);" title="There`s Nothing Holdin` Me Back 재생">There`s Nothing Holdin` Me Back</a>,
#  <a href="javascript:melon.link.goArtistDetail('776533');" title="Shawn Mendes - 페이지 이동">Shawn Mendes</a>,
#  <a href="javascript:melon.link.goArtistDetail('776533');" title="Shawn Mendes - 페이지 이동">Shawn Mendes</a>,
#  <a href="javascript:melon.link.goAlbumDetail('2689280');" title="Illuminate (New Deluxe Ver.) - 페이지 이동">Illuminate (New Deluxe Ver.)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10108597');" title="그때의 나, 그때의 우리">
#  <img alt="그때의 나, 그때의 우리 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/08/597/10108597_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30709103');" title="그때의 나, 그때의 우리 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30709103);" title="그때의 나, 그때의 우리 재생">그때의 나, 그때의 우리</a>,
#  <a href="javascript:melon.link.goArtistDetail('420527');" title="어반자카파 - 페이지 이동">어반자카파</a>,
#  <a href="javascript:melon.link.goArtistDetail('420527');" title="어반자카파 - 페이지 이동">어반자카파</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10108597');" title="그때의 나, 그때의 우리 - 페이지 이동">그때의 나, 그때의 우리</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10111029');" title="1-1=0 (NOTHING WITHOUT YOU)">
#  <img alt="1-1=0 (NOTHING WITHOUT YOU) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/11/029/10111029_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30725482');" title="Beautiful 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30725482);" title="Beautiful 재생">Beautiful</a>,
#  <a href="javascript:melon.link.goArtistDetail('1865973');" title="Wanna One (워너원) - 페이지 이동">Wanna One (워너원)</a>,
#  <a href="javascript:melon.link.goArtistDetail('1865973');" title="Wanna One (워너원) - 페이지 이동">Wanna One (워너원)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10111029');" title="1-1=0 (NOTHING WITHOUT YOU) - 페이지 이동">1-1=0 (NOTHING WITHOUT YOU)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10074454');" title="/// (너 먹구름 비)">
#  <img alt="/// (너 먹구름 비) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/74/454/10074454_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30492279');" title="비도 오고 그래서 (Feat. 신용재) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30492279);" title="비도 오고 그래서 (Feat. 신용재) 재생">비도 오고 그래서 (Feat. 신용재)</a>,
#  <a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a>,
#  <a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10074454');" title="/// (너 먹구름 비) - 페이지 이동">/// (너 먹구름 비)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10037969');" title="YOU NEVER WALK ALONE">
#  <img alt="YOU NEVER WALK ALONE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/37/969/10037969_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30244931');" title="봄날 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30244931);" title="봄날 재생">봄날</a>,
#  <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a>,
#  <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10037969');" title="YOU NEVER WALK ALONE - 페이지 이동">YOU NEVER WALK ALONE</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10016012');" title="1/24">
#  <img alt="1/24 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/16/012/10016012_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30099927');" title="노력 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30099927);" title="노력 재생">노력</a>,
#  <a href="javascript:melon.link.goArtistDetail('41499');" title="박원 - 페이지 이동">박원</a>,
#  <a href="javascript:melon.link.goArtistDetail('41499');" title="박원 - 페이지 이동">박원</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10016012');" title="1/24 - 페이지 이동">1/24</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10114851');" title="바보야">
#  <img alt="바보야 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/14/851/10114851_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30753213');" title="바보야 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30753213);" title="바보야 재생">바보야</a>,
#  <a href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a>,
#  <a href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10114851');" title="바보야 - 페이지 이동">바보야</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10057543');" title="종현 소품집 `이야기 Op.2`">
#  <img alt="종현 소품집 `이야기 Op.2` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/57/543/10057543_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30383758');" title="Lonely (Feat. 태연) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30383758);" title="Lonely (Feat. 태연) 재생">Lonely (Feat. 태연)</a>,
#  <a href="javascript:melon.link.goArtistDetail('544520');" title="종현 (JONGHYUN) - 페이지 이동">종현 (JONGHYUN)</a>,
#  <a href="javascript:melon.link.goArtistDetail('544520');" title="종현 (JONGHYUN) - 페이지 이동">종현 (JONGHYUN)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10057543');" title="종현 소품집 `이야기 Op.2` - 페이지 이동">종현 소품집 `이야기 Op.2`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10029181');" title="도깨비 OST Part.9">
#  <img alt="도깨비 OST Part.9 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/29/181/10029181_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30190630');" title="첫눈처럼 너에게 가겠다 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30190630);" title="첫눈처럼 너에게 가겠다 재생">첫눈처럼 너에게 가겠다</a>,
#  <a href="javascript:melon.link.goArtistDetail('629831');" title="에일리 - 페이지 이동">에일리</a>,
#  <a href="javascript:melon.link.goArtistDetail('629831');" title="에일리 - 페이지 이동">에일리</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10029181');" title="도깨비 OST Part.9 - 페이지 이동">도깨비 OST Part.9</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10089089');" title="SUNMI SPECIAL EDITION `가시나`">
#  <img alt="SUNMI SPECIAL EDITION `가시나` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/89/089/10089089_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30587846');" title="가시나 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30587846);" title="가시나 재생">가시나</a>,
#  <a href="javascript:melon.link.goArtistDetail('22938');" title="선미 - 페이지 이동">선미</a>,
#  <a href="javascript:melon.link.goArtistDetail('22938');" title="선미 - 페이지 이동">선미</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10089089');" title="SUNMI SPECIAL EDITION `가시나` - 페이지 이동">SUNMI SPECIAL EDITION `가시나`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`">
#  <img alt="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/36/531/10136531_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30878838');" title="고맙다 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30878838);" title="고맙다 재생">고맙다</a>,
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동">SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10105030');" title="WE`VE DONE SOMETHING WONDERFUL">
#  <img alt="WE`VE DONE SOMETHING WONDERFUL - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/05/030/10105030_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30688500');" title="연애소설 (Feat. 아이유) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30688500);" title="연애소설 (Feat. 아이유) 재생">연애소설 (Feat. 아이유)</a>,
#  <a href="javascript:melon.link.goArtistDetail('108356');" title="에픽하이 (EPIK HIGH) - 페이지 이동">에픽하이 (EPIK HIGH)</a>,
#  <a href="javascript:melon.link.goArtistDetail('108356');" title="에픽하이 (EPIK HIGH) - 페이지 이동">에픽하이 (EPIK HIGH)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10105030');" title="WE`VE DONE SOMETHING WONDERFUL - 페이지 이동">WE`VE DONE SOMETHING WONDERFUL</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10077879');" title="The Red Summer - Summer Mini Album">
#  <img alt="The Red Summer - Summer Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/77/879/10077879_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30512671');" title="빨간 맛 (Red Flavor) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30512671);" title="빨간 맛 (Red Flavor) 재생">빨간 맛 (Red Flavor)</a>,
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a>,
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10077879');" title="The Red Summer - Summer Mini Album - 페이지 이동">The Red Summer - Summer Mini Album</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2224353');" title="바람이 불었으면 좋겠어">
#  <img alt="바람이 불었으면 좋겠어 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/022/24/353/2224353_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('4383833');" title="바람이 불었으면 좋겠어 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',4383833);" title="바람이 불었으면 좋겠어 재생">바람이 불었으면 좋겠어</a>,
#  <a href="javascript:melon.link.goArtistDetail('500421');" title="길구봉구 - 페이지 이동">길구봉구</a>,
#  <a href="javascript:melon.link.goArtistDetail('500421');" title="길구봉구 - 페이지 이동">길구봉구</a>,
#  <a href="javascript:melon.link.goAlbumDetail('2224353');" title="바람이 불었으면 좋겠어 - 페이지 이동">바람이 불었으면 좋겠어</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10101927');" title="Yellow OST Part.2">
#  <img alt="Yellow OST Part.2 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/01/927/10101927_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30667988');" title="짙어져 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30667988);" title="짙어져 재생">짙어져</a>,
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a>,
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10101927');" title="Yellow OST Part.2 - 페이지 이동">Yellow OST Part.2</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10132956');" title="&amp;10">
#  <img alt="&amp;10 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/32/956/10132956_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30859636');" title="너 없는 시간들 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30859636);" title="너 없는 시간들 재생">너 없는 시간들</a>,
#  <a href="javascript:melon.link.goArtistDetail('236815');" title="다비치 - 페이지 이동">다비치</a>,
#  <a href="javascript:melon.link.goArtistDetail('236815');" title="다비치 - 페이지 이동">다비치</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10132956');" title="&amp;10 - 페이지 이동">&amp;10</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10122917');" title="Universe - 겨울 스페셜 앨범, 2017">
# ...
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10109208');" title="SEVENTEEN 2ND ALBUM `TEEN, AGE` - 페이지 이동">SEVENTEEN 2ND ALBUM `TEEN, AGE`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10131396');" title="Faces of Love">
#  <img alt="Faces of Love - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/31/396/10131396_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30851704');" title="HOLIDAY (Feat. DPR LIVE) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30851704);" title="HOLIDAY (Feat. DPR LIVE) 재생">HOLIDAY (Feat. DPR LIVE)</a>,
#  <a href="javascript:melon.link.goArtistDetail('514741');" title="수지 (SUZY) - 페이지 이동">수지 (SUZY)</a>,
#  <a href="javascript:melon.link.goArtistDetail('514741');" title="수지 (SUZY) - 페이지 이동">수지 (SUZY)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10131396');" title="Faces of Love - 페이지 이동">Faces of Love</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10006350');" title="Red Pill Blues (Deluxe Edition)">
#  <img alt="Red Pill Blues (Deluxe Edition) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/06/350/10006350_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30608019');" title="What Lovers Do (Feat. SZA) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30608019);" title="What Lovers Do (Feat. SZA) 재생">What Lovers Do (Feat. SZA)</a>,
#  <a href="javascript:melon.link.goArtistDetail('107721');" title="Maroon 5 - 페이지 이동">Maroon 5</a>,
#  <a href="javascript:melon.link.goArtistDetail('107721');" title="Maroon 5 - 페이지 이동">Maroon 5</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10006350');" title="Red Pill Blues (Deluxe Edition) - 페이지 이동">Red Pill Blues (Deluxe Edition)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10137197');" title="봉제선">
#  <img alt="봉제선 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/37/197/10137197_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30882218');" title="봉제선 (Feat. 수란) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30882218);" title="봉제선 (Feat. 수란) 재생">봉제선 (Feat. 수란)</a>,
#  <a href="javascript:melon.link.goArtistDetail('108358');" title="다이나믹 듀오 - 페이지 이동">다이나믹 듀오</a>,
#  <a href="javascript:melon.link.goArtistDetail('108358');" title="다이나믹 듀오 - 페이지 이동">다이나믹 듀오</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10137197');" title="봉제선 - 페이지 이동">봉제선</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2175137');" title="THE SECOND MINI ALBUM `여보세요`">
#  <img alt="THE SECOND MINI ALBUM `여보세요` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/021/75/137/2175137_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('4032981');" title="여보세요 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',4032981);" title="여보세요 재생">여보세요</a>,
#  <a href="javascript:melon.link.goArtistDetail('640891');" title="NU`EST - 페이지 이동">NU`EST</a>,
#  <a href="javascript:melon.link.goArtistDetail('640891');" title="NU`EST - 페이지 이동">NU`EST</a>,
#  <a href="javascript:melon.link.goAlbumDetail('2175137');" title="THE SECOND MINI ALBUM `여보세요` - 페이지 이동">THE SECOND MINI ALBUM `여보세요`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10122917');" title="Universe - 겨울 스페셜 앨범, 2017">
#  <img alt="Universe - 겨울 스페셜 앨범, 2017 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/22/917/10122917_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30806539');" title="지나갈 테니 (Been Through) 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30806539);" title="지나갈 테니 (Been Through) 재생">지나갈 테니 (Been Through)</a>,
#  <a href="javascript:melon.link.goArtistDetail('724619');" title="EXO - 페이지 이동">EXO</a>,
#  <a href="javascript:melon.link.goArtistDetail('724619');" title="EXO - 페이지 이동">EXO</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10122917');" title="Universe - 겨울 스페셜 앨범, 2017 - 페이지 이동">Universe - 겨울 스페셜 앨범, 2017</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10142642');" title="1st Album `10 Stories`">
#  <img alt="1st Album `10 Stories` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/42/642/10142642_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30917488');" title="True Love 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30917488);" title="True Love 재생">True Love</a>,
#  <a href="javascript:melon.link.goArtistDetail('672262');" title="김성규 - 페이지 이동">김성규</a>,
#  <a href="javascript:melon.link.goArtistDetail('672262');" title="김성규 - 페이지 이동">김성규</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10142642');" title="1st Album `10 Stories` - 페이지 이동">1st Album `10 Stories`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`">
#  <img alt="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/36/531/10136531_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30878839');" title="지금 널 찾아가고 있어 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30878839);" title="지금 널 찾아가고 있어 재생">지금 널 찾아가고 있어</a>,
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동">SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10100941');" title="W, HERE">
#  <img alt="W, HERE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/00/941/10100941_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30661885');" title="WHERE YOU AT 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30661885);" title="WHERE YOU AT 재생">WHERE YOU AT</a>,
#  <a href="javascript:melon.link.goArtistDetail('1816966');" title="뉴이스트 W - 페이지 이동">뉴이스트 W</a>,
#  <a href="javascript:melon.link.goArtistDetail('1816966');" title="뉴이스트 W - 페이지 이동">뉴이스트 W</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10100941');" title="W, HERE - 페이지 이동">W, HERE</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10132945');" title="Return">
#  <img alt="Return - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/32/945/10132945_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30859595');" title="LONG TIME NO SEE 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30859595);" title="LONG TIME NO SEE 재생">LONG TIME NO SEE</a>,
#  <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a>,
#  <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10132945');" title="Return - 페이지 이동">Return</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10070846');" title="남이 될 수 있을까">
#  <img alt="남이 될 수 있을까 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/70/846/10070846_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30468654');" title="남이 될 수 있을까 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30468654);" title="남이 될 수 있을까 재생">남이 될 수 있을까</a>,
#  <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a>,
#  <a href="javascript:melon.link.goArtistDetail('714975');" title="스무살 - 페이지 이동">스무살</a>,
#  <a href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 - 페이지 이동">볼빨간사춘기</a>,
#  <a href="javascript:melon.link.goArtistDetail('714975');" title="스무살 - 페이지 이동">스무살</a>,
#  <a class="ellipsis" href="javascript:melon.link.goArtistDetail('792022');" title="볼빨간사춘기 페이지 이동">볼빨간사춘기</a>,
#  <a class="ellipsis" href="javascript:melon.link.goArtistDetail('714975');" title="스무살 페이지 이동">스무살</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10070846');" title="남이 될 수 있을까 - 페이지 이동">남이 될 수 있을까</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2243842');" title="Chandelier (Single)">
#  <img alt="Chandelier (Single) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/022/43/842/2243842_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('4534974');" title="Chandelier 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',4534974);" title="Chandelier 재생">Chandelier</a>,
#  <a href="javascript:melon.link.goArtistDetail('54103');" title="Sia - 페이지 이동">Sia</a>,
#  <a href="javascript:melon.link.goArtistDetail('54103');" title="Sia - 페이지 이동">Sia</a>,
#  <a href="javascript:melon.link.goAlbumDetail('2243842');" title="Chandelier (Single) - 페이지 이동">Chandelier (Single)</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10097112');" title="LOVE YOURSELF 承 `Her`">
#  <img alt="LOVE YOURSELF 承 `Her` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/97/112/10097112_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30637983');" title="Best Of Me 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30637983);" title="Best Of Me 재생">Best Of Me</a>,
#  <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a>,
#  <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10097112');" title="LOVE YOURSELF 承 `Her` - 페이지 이동">LOVE YOURSELF 承 `Her`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`">
#  <img alt="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/36/531/10136531_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30878837');" title="Thinkin` about you 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30878837);" title="Thinkin` about you 재생">Thinkin` about you</a>,
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 - 페이지 이동">세븐틴</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10136531');" title="SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT` - 페이지 이동">SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('5284');" title="Wolf and Sheep">
#  <img alt="Wolf and Sheep - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/000/05/284/5284_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('91264');" title="행복 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',91264);" title="행복 재생">행복</a>,
#  <a href="javascript:melon.link.goArtistDetail('100008');" title="H.O.T. - 페이지 이동">H.O.T.</a>,
#  <a href="javascript:melon.link.goArtistDetail('100008');" title="H.O.T. - 페이지 이동">H.O.T.</a>,
#  <a href="javascript:melon.link.goAlbumDetail('5284');" title="Wolf and Sheep - 페이지 이동">Wolf and Sheep</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10083276');" title="`Be One` - Buzz The 1st Mini Album">
#  <img alt="`Be One` - Buzz The 1st Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/83/276/10083276_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30550293');" title="사랑하지 않은 것처럼 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30550293);" title="사랑하지 않은 것처럼 재생">사랑하지 않은 것처럼</a>,
#  <a href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a>,
#  <a href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10083276');" title="`Be One` - Buzz The 1st Mini Album - 페이지 이동">`Be One` - Buzz The 1st Mini Album</a>,
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10135777');" title="마지막으로 안아도 될까">
#  <img alt="마지막으로 안아도 될까 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/35/777/10135777_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30874386');" title="마지막으로 안아도 될까 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('19041201',30874386);" title="마지막으로 안아도 될까 재생">마지막으로 안아도 될까</a>,
#  <a href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a>,
#  <a href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10135777');" title="마지막으로 안아도 될까 - 페이지 이동">마지막으로 안아도 될까</a>]

# %%
#frm > div > table > tbody
