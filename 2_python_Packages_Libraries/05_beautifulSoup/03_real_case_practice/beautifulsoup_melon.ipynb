# %%
import requests
import re
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://www.melon.com/chart/day/index.htm"

# %%
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
tmp_tag = soup.find('tbody')

# %% [markdown]
# 순위

# %%
tmp_tag.find_all('span', 'rank')[0].get_text()
# Out:
# '1'

# %%
tmp_tag.select('.ellipsis.rank01 a')[0].get_text()
# Out:
# 'EVERYDAY'

# %%
tmp_tag.select('.ellipsis.rank02 .checkEllipsis')[0].get_text()
# Out:
# 'WINNER'

# %%
tmp_tag.select('.ellipsis.rank03 a')[0].get_text()
# Out:
# 'EVERYD4Y'

# %%
import requests
import re
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import datetime

url_1 = "https://www.melon.com/chart/day/index.htm"
url_2 = "https://www.melon.com/chart/day/index.htm#params%5Bidx%5D=51"

melon_day = pd.DataFrame(columns = ["Ranking", "Song", "Artist", "Album"])

# rank 1~50
html = urlopen(url_1)
soup = BeautifulSoup(html, 'html.parser')
tmp_tag = soup_1.find('tbody')

for i in range(50):

    rank = tmp_tag.find_all('span', 'rank')[i].get_text()
    song = tmp_tag.select('.ellipsis.rank01 a')[i].get_text()
    artist = tmp_tag.select('.ellipsis.rank02 .checkEllipsis')[i].get_text()
    album = tmp_tag.select('.ellipsis.rank03 a')[i].get_text()

    data = {"Ranking" : rank, 
            "Song" : song, 
            "Artist" : artist, 
            "Album" : album, }

    melon_day.loc[len(melon_day)] = data


# rank 51~100
html = urlopen(url_2)
soup = BeautifulSoup(html, 'html.parser')

tmp_tag = soup.find('tbody')

for i in range(50):

    rank = tmp_tag.find_all('span', 'rank')[i].get_text()
    song = tmp_tag.select('.ellipsis.rank01 a')[i].get_text()
    artist = tmp_tag.select('.ellipsis.rank02 .checkEllipsis')[i].get_text()
    album = tmp_tag.select('.ellipsis.rank03 a')[i].get_text()

    data = {"Ranking" : rank, 
            "Song" : song, 
            "Artist" : artist, 
            "Album" : album, }

    melon_day.loc[len(melon_day)] = data


# melon_day = melon_day.set_index('Ranking')

# now = datetime.datetime.now()
# current_time = now.strftime("%Y-%m-%d")

# melon_day.to_csv('melon_daily_100_(' + str(current_time) + ')' )
# Out:
#    Ranking                           Song                              Artist  \
# 0        1                       EVERYDAY                              WINNER
# 1        2         바코드 (Prod. GroovyRoom)            김하온 (HAON), 이병재 (Vinxen)
# 2        3                            꽃 길                             BIGBANG
# 3        4                       별이 빛나는 밤                                 마마무
# 4        5         사랑을 했다 (LOVE SCENARIO)                                iKON
# 5        6                             뿜뿜                     모모랜드 (MOMOLAND)
# 6        7                  북 (Prod. SLO)  배연서 (WEBSTER B), 오담률 (CHIN CHILLA)
# 7        8                           그날처럼                                 장덕철
# 8        9            Jenga (Feat. Gaeko)                         헤이즈 (Heize)
# 9       10                            You                                멜로망스
# 10      11                         My Way                        이수 (엠씨 더 맥스)
# ...
